# %%
import numpy as np
from sklearn import datasets
from sklearn.svm import SVC
from sklearn.semi_supervised import SelfTrainingClassifier
from gensim.models import Word2Vec
from sklearn.model_selection import train_test_split, GridSearchCV
import numpy as np
import pandas as pd
import pickle
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv("processed_train.csv")

# %%
df
# Out:
#        Unnamed: 0     id                                              tweet  \
# 0               0  86426              ['ask', 'native', 'american', 'take']
# 1               1  90194  ['go', 'home', '’', 'drunk', 'maga', 'trump', ...
# 2               2  16820  ['amazon', 'investigating', 'chinese', 'employ...
# 3               3  62688  ['someone', 'shouldve', 'taken', 'piece', 'shi...
# 4               4  43605  ['obama', 'wanted', 'liberal', 'amp', 'illegal...
# ...           ...    ...                                                ...
# 13235       13235  95338  ['sometimes', 'get', 'strong', 'vibe', 'people...
# 13236       13236  67210  ['benidorm', '✅', 'creamfields', '✅', 'maga', ...
# 13237       13237  82921      ['report', 'garbage', 'dont', 'give', 'crap']
# 13238       13238  27429                                          ['pussy']
# 13239       13239  46552  ['spanishrevenge', 'v', 'justice', 'human', 'r...
#
#       subtask_a subtask_b subtask_c
# 0           OFF       UNT       NaN
# 1           OFF       TIN       IND
# 2           NOT       NaN       NaN
# 3           OFF       UNT       NaN
# 4           NOT       NaN       NaN
# ...         ...       ...       ...
# 13235       OFF       TIN       IND
# 13236       NOT       NaN       NaN
# 13237       OFF       TIN       OTH
# 13238       OFF       UNT       NaN
# 13239       NOT       NaN       NaN
#
# [13240 rows x 6 columns]

# %% [markdown]
# ## Removing Redundant Axes

# %%
df = df.drop(['Unnamed: 0', 'subtask_b', 'subtask_c', 'id'], axis=1)

# %%
df
# Out:
#                                                    tweet subtask_a
# 0                  ['ask', 'native', 'american', 'take']       OFF
# 1      ['go', 'home', '’', 'drunk', 'maga', 'trump', ...       OFF
# 2      ['amazon', 'investigating', 'chinese', 'employ...       NOT
# 3      ['someone', 'shouldve', 'taken', 'piece', 'shi...       OFF
# 4      ['obama', 'wanted', 'liberal', 'amp', 'illegal...       NOT
# ...                                                  ...       ...
# 13235  ['sometimes', 'get', 'strong', 'vibe', 'people...       OFF
# 13236  ['benidorm', '✅', 'creamfields', '✅', 'maga', ...       NOT
# 13237      ['report', 'garbage', 'dont', 'give', 'crap']       OFF
# 13238                                          ['pussy']       OFF
# 13239  ['spanishrevenge', 'v', 'justice', 'human', 'r...       NOT
#
# [13240 rows x 2 columns]

# %% [markdown]
# ## Renaming Columns

# %%
df = df.rename(columns={'subtask_a': 'Offensive'})

# %%
df
# Out:
#                                                    tweet Offensive
# 0                  ['ask', 'native', 'american', 'take']       OFF
# 1      ['go', 'home', '’', 'drunk', 'maga', 'trump', ...       OFF
# 2      ['amazon', 'investigating', 'chinese', 'employ...       NOT
# 3      ['someone', 'shouldve', 'taken', 'piece', 'shi...       OFF
# 4      ['obama', 'wanted', 'liberal', 'amp', 'illegal...       NOT
# ...                                                  ...       ...
# 13235  ['sometimes', 'get', 'strong', 'vibe', 'people...       OFF
# 13236  ['benidorm', '✅', 'creamfields', '✅', 'maga', ...       NOT
# 13237      ['report', 'garbage', 'dont', 'give', 'crap']       OFF
# 13238                                          ['pussy']       OFF
# 13239  ['spanishrevenge', 'v', 'justice', 'human', 'r...       NOT
#
# [13240 rows x 2 columns]

# %% [markdown]
# ## Converting Offensive to Numerical Value

# %%
def off(cls):
    if cls =='OFF':
        return 1
    elif cls == 'NOT':
        return 0

# %%
df["Offensive"] = df["Offensive"].apply(off)

# %%
df
# Out:
#                                                    tweet  Offensive
# 0                  ['ask', 'native', 'american', 'take']          1
# 1      ['go', 'home', '’', 'drunk', 'maga', 'trump', ...          1
# 2      ['amazon', 'investigating', 'chinese', 'employ...          0
# 3      ['someone', 'shouldve', 'taken', 'piece', 'shi...          1
# 4      ['obama', 'wanted', 'liberal', 'amp', 'illegal...          0
# ...                                                  ...        ...
# 13235  ['sometimes', 'get', 'strong', 'vibe', 'people...          1
# 13236  ['benidorm', '✅', 'creamfields', '✅', 'maga', ...          0
# 13237      ['report', 'garbage', 'dont', 'give', 'crap']          1
# 13238                                          ['pussy']          1
# 13239  ['spanishrevenge', 'v', 'justice', 'human', 'r...          0
#
# [13240 rows x 2 columns]

# %% [markdown]
# ## Adding Unlabelled Data

# %%
df_unlab = pd.read_csv("processed_unlab.csv").drop(['Unnamed: 0', 'id'], axis=1)

# %%
df_unlab
# Out:
#                                                   tweet
# 0     ['q', 'wheres', 'server', 'dump', 'nike', 'dec...
# 1     ['constitution', 'day', 'revered', 'conservati...
# 2     ['foxnews', 'nra', 'maga', 'potus', 'trump', '...
# 3     ['watching', 'boomer', 'getting', 'news', 'sti...
# 4     ['pasaran', 'unity', 'demo', 'oppose', 'farrig...
# ...                                                 ...
# 1308  ['stop', 'etchecopar', 'fuck', '🖕', '🖕', '🖕', ...
# 1309  ['antifa', 'mentally', 'unstable', 'cowards', ...
# 1310  ['browning', 'looked', 'like', 'dog', 'shit', ...
# 1311             ['two', 'taste', 'like', 'ass', 'url']
# 1312  ['despicable', 'dems', 'lie', 'rifles', 'dem',...
#
# [1313 rows x 1 columns]

# %%
values = [-1 for i in range(len(df_unlab))]

y_unlab = pd.DataFrame({'Offensive':values})

# %%
y_unlab
# Out:
#       Offensive
# 0            -1
# 1            -1
# 2            -1
# 3            -1
# 4            -1
# ...         ...
# 1308         -1
# 1309         -1
# 1310         -1
# 1311         -1
# 1312         -1
#
# [1313 rows x 1 columns]

# %%
df_unlab
# Out:
#                                                   tweet
# 0     ['q', 'wheres', 'server', 'dump', 'nike', 'dec...
# 1     ['constitution', 'day', 'revered', 'conservati...
# 2     ['foxnews', 'nra', 'maga', 'potus', 'trump', '...
# 3     ['watching', 'boomer', 'getting', 'news', 'sti...
# 4     ['pasaran', 'unity', 'demo', 'oppose', 'farrig...
# ...                                                 ...
# 1308  ['stop', 'etchecopar', 'fuck', '🖕', '🖕', '🖕', ...
# 1309  ['antifa', 'mentally', 'unstable', 'cowards', ...
# 1310  ['browning', 'looked', 'like', 'dog', 'shit', ...
# 1311             ['two', 'taste', 'like', 'ass', 'url']
# 1312  ['despicable', 'dems', 'lie', 'rifles', 'dem',...
#
# [1313 rows x 1 columns]

# %%
df['tweet']
# Out:
# 0                    ['ask', 'native', 'american', 'take']
# 1        ['go', 'home', '’', 'drunk', 'maga', 'trump', ...
# 2        ['amazon', 'investigating', 'chinese', 'employ...
# 3        ['someone', 'shouldve', 'taken', 'piece', 'shi...
# 4        ['obama', 'wanted', 'liberal', 'amp', 'illegal...
#                                ...
# 13235    ['sometimes', 'get', 'strong', 'vibe', 'people...
# 13236    ['benidorm', '✅', 'creamfields', '✅', 'maga', ...
# 13237        ['report', 'garbage', 'dont', 'give', 'crap']
# 13238                                            ['pussy']
# 13239    ['spanishrevenge', 'v', 'justice', 'human', 'r...
# Name: tweet, Length: 13240, dtype: object

# %% [markdown]
# ## Splitting into train and test

# %%
X_train, X_test, y_train, y_test = train_test_split(df['tweet'], df['Offensive'], stratify=df['Offensive'], shuffle=0)

# %%
X_train = X_train.reset_index().drop(['index'], axis=1)
X_train
# Out:
#                                                   tweet
# 0     ['please', 'stop', 'nice', 'lying', 'obstructi...
# 1     ['sure', 'bout', 'antifa', 'notion', 'open', '...
# 2     ['prison', 'time', 'youre', 'going', 'get', 'm...
# 3     ['decent', 'anywhere', 'people', 'respect', 'i...
# 4     ['best', 'part', 'read', 'exchange', 'thread',...
# ...                                                 ...
# 9925  ['opportunist', 'max', 'evil', 'lier', 'also',...
# 9926  ['lt', 'help', 'call', 'father', 'let', 'know'...
# 9927  ['suicide', 'mission', 'dont', 'put', 'bench',...
# 9928                               ['traitor', 'think']
# 9929  ['there', 'murder', 'gun', 'death', 'state', '...
#
# [9930 rows x 1 columns]

# %%
X_train_unlab = X_train.append(df_unlab).reset_index().drop(['index'], axis=1)

# %%
X_train_unlab
# Out:
#                                                    tweet
# 0      ['please', 'stop', 'nice', 'lying', 'obstructi...
# 1      ['sure', 'bout', 'antifa', 'notion', 'open', '...
# 2      ['prison', 'time', 'youre', 'going', 'get', 'm...
# 3      ['decent', 'anywhere', 'people', 'respect', 'i...
# 4      ['best', 'part', 'read', 'exchange', 'thread',...
# ...                                                  ...
# 11238  ['stop', 'etchecopar', 'fuck', '🖕', '🖕', '🖕', ...
# 11239  ['antifa', 'mentally', 'unstable', 'cowards', ...
# 11240  ['browning', 'looked', 'like', 'dog', 'shit', ...
# 11241             ['two', 'taste', 'like', 'ass', 'url']
# 11242  ['despicable', 'dems', 'lie', 'rifles', 'dem',...
#
# [11243 rows x 1 columns]

# %%
X_train = X_train['tweet']

# %%
X_train
# Out:
# 0       ['please', 'stop', 'nice', 'lying', 'obstructi...
# 1       ['sure', 'bout', 'antifa', 'notion', 'open', '...
# 2       ['prison', 'time', 'youre', 'going', 'get', 'm...
# 3       ['decent', 'anywhere', 'people', 'respect', 'i...
# 4       ['best', 'part', 'read', 'exchange', 'thread',...
#                               ...
# 9925    ['opportunist', 'max', 'evil', 'lier', 'also',...
# 9926    ['lt', 'help', 'call', 'father', 'let', 'know'...
# 9927    ['suicide', 'mission', 'dont', 'put', 'bench',...
# 9928                                 ['traitor', 'think']
# 9929    ['there', 'murder', 'gun', 'death', 'state', '...
# Name: tweet, Length: 9930, dtype: object

# %%
X_train_unlab = X_train_unlab['tweet']
X_train_unlab
# Out:
# 0        ['please', 'stop', 'nice', 'lying', 'obstructi...
# 1        ['sure', 'bout', 'antifa', 'notion', 'open', '...
# 2        ['prison', 'time', 'youre', 'going', 'get', 'm...
# 3        ['decent', 'anywhere', 'people', 'respect', 'i...
# 4        ['best', 'part', 'read', 'exchange', 'thread',...
#                                ...
# 11238    ['stop', 'etchecopar', 'fuck', '🖕', '🖕', '🖕', ...
# 11239    ['antifa', 'mentally', 'unstable', 'cowards', ...
# 11240    ['browning', 'looked', 'like', 'dog', 'shit', ...
# 11241               ['two', 'taste', 'like', 'ass', 'url']
# 11242    ['despicable', 'dems', 'lie', 'rifles', 'dem',...
# Name: tweet, Length: 11243, dtype: object

# %%
X_test = X_test.reset_index().drop(['index'], axis=1)
X_test
# Out:
#                                                   tweet
# 0     ['time', 'political', 'correctness', 'lie', 'e...
# 1     ['speak', 'trump', 'family', 'become', 'punchi...
# 2     ['showing', 'way', 'others', 'great', 'leader'...
# 3                        ['far', 'kind', '😍', '😊', '🤗']
# 4     ['url', 'isnt', 'peter', 'strzok', 'lisa', 'pa...
# ...                                                 ...
# 3305                      ['reason', '’', 'wife', 'as']
# 3306  ['idk', 'think', 'herbut', 'eye', 'like', 'rsh...
# 3307  ['dier', 'imagine', 'durham', 'coming', 'even'...
# 3308  ['uh', 'signature', 'record', 'genius', '🚂', '...
# 3309  ['withdraw', 'trump', 'whole', 'list', 'conser...
#
# [3310 rows x 1 columns]

# %%
X_test = X_test['tweet']
X_test
# Out:
# 0       ['time', 'political', 'correctness', 'lie', 'e...
# 1       ['speak', 'trump', 'family', 'become', 'punchi...
# 2       ['showing', 'way', 'others', 'great', 'leader'...
# 3                          ['far', 'kind', '😍', '😊', '🤗']
# 4       ['url', 'isnt', 'peter', 'strzok', 'lisa', 'pa...
#                               ...
# 3305                        ['reason', '’', 'wife', 'as']
# 3306    ['idk', 'think', 'herbut', 'eye', 'like', 'rsh...
# 3307    ['dier', 'imagine', 'durham', 'coming', 'even'...
# 3308    ['uh', 'signature', 'record', 'genius', '🚂', '...
# 3309    ['withdraw', 'trump', 'whole', 'list', 'conser...
# Name: tweet, Length: 3310, dtype: object

# %%
y_train = y_train.reset_index().drop(['index'], axis=1)
y_train
# Out:
#       Offensive
# 0             0
# 1             0
# 2             1
# 3             0
# 4             0
# ...         ...
# 9925          1
# 9926          0
# 9927          0
# 9928          1
# 9929          1
#
# [9930 rows x 1 columns]

# %%
y_test = y_test.reset_index().drop(['index'], axis=1)
y_test
# Out:
#       Offensive
# 0             0
# 1             0
# 2             0
# 3             0
# 4             1
# ...         ...
# 3305          1
# 3306          1
# 3307          0
# 3308          0
# 3309          0
#
# [3310 rows x 1 columns]

# %%
y_train_unlab = y_train.append(y_unlab)
y_train_unlab
# Out:
#       Offensive
# 0             0
# 1             0
# 2             1
# 3             0
# 4             0
# ...         ...
# 1308         -1
# 1309         -1
# 1310         -1
# 1311         -1
# 1312         -1
#
# [11243 rows x 1 columns]

# %%
y_train_unlab = y_train_unlab.reset_index().drop(['index'], axis = 1)
y_train_unlab
# Out:
#        Offensive
# 0              0
# 1              0
# 2              1
# 3              0
# 4              0
# ...          ...
# 11238         -1
# 11239         -1
# 11240         -1
# 11241         -1
# 11242         -1
#
# [11243 rows x 1 columns]

# %% [markdown]
# ### TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
vect_gram = TfidfVectorizer(analyzer='word', stop_words='english', ngram_range = (1, 3), max_df=5)

# %% [markdown]
# ### Testing on Supervised Classifiers to get Hyperparameters

# %%
X_train_gram = vect_gram.fit_transform(X_train)

# %%
X_train_gram
# Out:
# <9930x154235 sparse matrix of type '<class 'numpy.float64'>'
# 	with 170504 stored elements in Compressed Sparse Row format>

# %%
vect_gram.get_feature_names()
# Out:
# ['aa',
#  'aa mr',
#  'aa mr bean',
#  'aa sary',
#  'aa sary liberal',
#  'aaa',
#  'aaa aaay',
#  'aaa aaay eer',
#  'aaa dibales',
#  'aaa dibales dong',
#  'aaa exciting',
#  'aaa exciting majority',
#  'aaah',
#  'aaah thank',
#  'aaah thank sm',
#  'aaahh',
#  'aaahh scribe',
#  'aaahh scribe run',
#  'aaay',
#  'aaay eer',
#  'aaay eer url',
#  'aaron',
#  'aaron bank',
#  'aaron bank amp',
#  'aaron barely',
#  'aaron barely year',
#  'aaron hernandez',
#  'aaron hernandez know',
#  'aaron rodgers',
#  'aaron rodgers win',
#  'aarp',
#  'aarp stop',
#  'aarp stop biased',
#  'aasertions',
#  'aasertions voting',
#  'aasertions voting amp',
#  'ab confirm',
#  'ab confirm judge',
#  'ab dumb',
#  'ab dumb shane',
#  'ab literally',
#  'ab literally offense',
#  'ab lot',
#  'ab lot defined',
#  'ab player',
#  'ab player today',
#  'ab winning',
#  'ab winning rugby',
#  'aba',
#  'aba leadership',
#  'aba leadership champion',
#  'aback',
#  'abandon',
#  'abandon brexit',
#  'abandon brexit liberal',
#  'abandon conservative',
#  'abandon conservative want',
#  'abbott',
#  'abbott conservative',
#  'abbott conservative win',
#  'abbott meeting',
#  'abbott meeting solving',
#  'abc',
#  'abc amp',
#  'abc amp damn',
#  'abc let',
#  'abc let anti',
#  'abc let spew',
#  'abcnews',
#  'abcnews cbsnews',
#  'abducted',
#  'abducted heck',
#  'abducted heck going',
#  'abetterway',
#  'abetterway url',
#  'abetting',
#  'abhorrent',
#  'abhorrent hung',
#  'abhorrent hung woman',
#  'abhorrent inexcusable',
#  'abhorrent inexcusable fearless',
#  'abi',
#  'abi right',
#  'abide',
#  'abide patriotic',
#  'abide patriotic view',
#  'abiding american',
#  'abiding american stance',
#  'abiding citizen armed',
#  'abiding citizen defend',
#  'abiding citizen dont',
#  'abiding citizen law',
#  'abiding citizen subvert',
#  'abiding ignoring',
#  'abiding ignoring fact',
#  'abiding nra',
#  'abiding nra membbbqers',
#  'abiding nra member',
#  'abigot',
#  'abigot maga',
#  'abigot maga kag',
#  'ability create',
#  'ability create monster',
#  'ability defend',
#  'ability face',
#  'ability face brussels',
#  'ability learn',
#  'ability learn think',
#  'ability stop',
#  'ability stop choose',
#  'ability tell',
#  'ability tell truth',
#  'ability turn',
#  'ability whats',
#  'ability whats wrong',
#  'abject',
#  'abject failure',
#  'abject failure dismissed',
#  'abject hypocrisy',
#  'abject hypocrisy url',
#  'able accept',
#  'able accept reality',
#  'able arm',
#  'able arm safe',
#  'able attack',
#  'able attack future',
#  'able bear',
#  'able bear arm',
#  'able carry',
#  'able carry concealed',
#  'able communicate',
#  'able communicate like',
#  'able confirm',
#  'able confirm content',
#  'able defend',
#  'able defend loved',
#  'able diagnose',
#  'able diagnose accuser',
#  'able disowned',
#  'able disowned people',
#  'able doesnt',
#  'able doesnt matter',
#  'able earn',
#  'able earn decent',
#  'able eat',
#  'able eat mind',
#  'able eat pussy',
#  'able eat shop',
#  'able forget',
#  'able forget horrible',
#  'able gop',
#  'able gop courage',
#  'able grasp',
#  'able grasp consequencesyour',
#  'able hold',
#  'able hold short',
#  'able law',
#  'able law enforcement',
#  'able live',
#  'able live planet',
#  'able make',
#  'able make january',
#  'able page',
#  'able page universal',
#  'able pay',
#  'able pay fee',
#  'able play',
#  'able play blame',
#  'able problem',
#  'able problem solve',
#  'able promote',
#  'able promote amazing',
#  'able provide',
#  'able provide assistant',
#  'able pugchat',
#  'able pugchat buddy',
#  'able question',
#  'able question consensus',
#  'able raise',
#  'able raise ugliness',
#  'able reconnect',
#  'able reconnect mind',
#  'able relate',
#  'able relate character',
#  'able restore',
#  'able restore hope',
#  'able secure',
#  'able secure trade',
#  'able tell',
#  'able tell world',
#  'able tell yelling',
#  'able thing',
#  'able thing like',
#  'able time',
#  'able time released',
#  'able trade',
#  'able understand',
#  'able understand able',
#  'able understand people',
#  'able use',
#  'able use scratch',
#  'able vote',
#  'able vote dont',
#  'ableg',
#  'ableg cdnpoli',
#  'aboard',
#  'aboard maga',
#  'aboard maga url',
#  'aboard proudly',
#  'aboard proudly following',
#  'aboard trump',
#  'aboard trump train',
#  'abolish',
#  'abolish government',
#  'abolish government joining',
#  'abolish ice',
#  'abolish ice believe',
#  'abolish ice msm',
#  'abolish nd',
#  'abolish nd amendment',
#  'abolition',
#  'abolition rhetoric',
#  'abolition rhetoric used',
#  'abomination',
#  'abort',
#  'abort computer',
#  'abort computer email',
#  'aborting',
#  'aborting existence',
#  'aborting existence right',
#  'aborting minority',
#  'aborting minority like',
#  'abortion alive',
#  'abortion alive abortion',
#  'abortion considers',
#  'abortion considers abortion',
#  'abortion control',
#  'abortion control free',
#  'abortion demand',
#  'abortion demand want',
#  'abortion favor',
#  'abortion favor stfu',
#  'abortion form',
#  'abortion form slavery',
#  'abortion gun',
#  'abortion gun control',
#  'abortion illegal',
#  'abortion illegal hear',
#  'abortion india',
#  'abortion india legal',
#  'abortion inducing',
#  'abortion inducing drug',
#  'abortion legalizing',
#  'abortion legalizing cannabis',
#  'abortion lifeanddeath',
#  'abortion lifeanddeath circumstance',
#  'abortion like',
#  'abortion like bare',
#  'abortion murder',
#  'abortion murder chelsea',
#  'abortion paid',
#  'abortion paid government',
#  'abortion promotes',
#  'abortion promotes gun',
#  'abortion rare',
#  'abortion rare amp',
#  'abortion restricted',
#  'abortion restricted rd',
#  'abortion said',
#  'abortion said really',
#  'abortion sanctity',
#  'abortion sanctity life',
#  'abortion scotus',
#  'abortion scotus pick',
#  'abortion stake',
#  'abortion stake november',
#  'abortion support',
#  'abortion support president',
#  'abortion thats',
#  'abortion thats politics',
#  'abortion try',
#  'abortion try method',
#  'abortion victim',
#  'abortionbecause',
#  'abortionbecause body',
#  'abortionbecause body explain',
#  'abortionnot',
#  'abortionnot truewomen',
#  'abortionnot truewomen right',
#  'abortionwar',
#  'abortionwar poc',
#  'abortionwar poc amp',
#  'abound',
#  'abraham',
#  'abraham lincoln',
#  'abraham lincoln tcot',
#  'abramoff',
#  'abramoff kid',
#  'abramoff kid stupid',
#  'abroad',
#  'abroad lnvestigation',
#  'abroad lnvestigation iniated',
#  'absence',
#  'absence law',
#  'absence law issue',
#  'absentee',
#  'absentee ballot',
#  'absentee time',
#  'absentee time midterm',
#  'abso',
#  'abso shite',
#  'abso shite quality',
#  'absofuckinglutely',
#  'absofuckinglutely shit',
#  'absolute favorite',
#  'absolute favorite sharp',
#  'absolute game',
#  'absolute game changer',
#  'absolute joke',
#  'absolute queen',
#  'absolute queen thank',
#  'absolute shit',
#  'absolute shit human',
#  'absolute shite',
#  'absolute shite car',
#  'absolute treason',
#  'absolute waste',
#  'absolute waste moneyhow',
#  'absolute worse',
#  'absolute worse period',
#  'absolute worst',
#  'absolute worst elizabethholmes',
#  'absolute worst thatno',
#  'absolutely amazing',
#  'absolutely beautiful',
#  'absolutely beautiful gorgeous',
#  'absolutely came',
#  'absolutely change',
#  'absolutely change thing',
#  'absolutely close',
#  'absolutely close border',
#  'absolutely comparison',
#  'absolutely conservative',
#  'absolutely conservative strong',
#  'absolutely correct',
#  'absolutely correct question',
#  'absolutely disgusting',
#  'absolutely dynamic',
#  'absolutely dynamic wrote',
#  'absolutely ego',
#  'absolutely ego jericho',
#  'absolutely enforce',
#  'absolutely enforce consistently',
#  'absolutely fucking',
#  'absolutely fucking bye',
#  'absolutely fucking palate',
#  'absolutely gain',
#  'absolutely gain coming',
#  'absolutely going',
#  'absolutely going mad',
#  'absolutely gorgeous',
#  'absolutely hate',
#  'absolutely hate white',
#  'absolutely hilarious',
#  'absolutely hilarious liberal',
#  'absolutely including',
#  'absolutely including internet',
#  'absolutely insane',
#  'absolutely insane liberal',
#  'absolutely know',
#  'absolutely know dems',
#  'absolutely liberal',
#  'absolutely liberal upside',
#  'absolutely love',
#  'absolutely love serenahowever',
#  'absolutely nail',
#  'absolutely nail coffin',
#  'absolutely nfw',
#  'absolutely point',
#  'absolutely point debating',
#  'absolutely preferring',
#  'absolutely preferring em',
#  'absolutely right',
#  'absolutely right build',
#  'absolutely right fool',
#  'absolutely right point',
#  'absolutely right smdh',
#  'absolutely sensational',
#  'absolutely special',
#  'absolutely stop',
#  'absolutely stop dream',
#  'absolutely stupid',
#  'absolutely stupid double',
#  'absolutely suck',
#  'absolutely suck max',
#  'absolutely unbelievable',
#  'absolutely unbelievable protest',
#  'absolutely unemployable',
#  'absolutely url',
#  'absolutely void',
#  'absolutely void constructive',
#  'absolutely wipe',
#  'absolutely wipe floor',
#  'absolutely wrong',
#  'absolutely wrong victim',
#  'absolutely zero',
#  'absolutely zero corroboration',
#  'absolutely zero intention',
#  'absolutist',
#  'absolutist care',
#  'absolutist care offends',
#  'absurd',
#  'absurd conspiracy',
#  'absurd conspiracy theory',
#  'absurd left',
#  'absurd left fielding',
#  'absurd read',
#  'absurd read history',
#  'absurd spending',
#  'absurd spending conservative',
#  'abt',
#  'abt gun',
#  'abt gun control',
#  'abt hour',
#  'abt hour myrtle',
#  'abt know',
#  'abt know donald',
#  'abt thing',
#  'abt thing love',
#  'abuse ahead',
#  'abuse ahead believing',
#  'abuse appears',
#  'abuse appears commercial',
#  'abuse charge',
#  'abuse charge url',
#  'abuse credible',
#  'abuse credible truth',
#  'abuse document',
#  'abuse document remain',
#  'abuse domestic',
#  'abuse domestic abuse',
#  'abuse endanger',
#  'abuse endanger child',
#  'abuse hey',
#  'abuse hey stay',
#  'abuse himseem',
#  'abuse himseem like',
#  'abuse hope',
#  'abuse hope didnt',
#  'abuse kavanaugh',
#  'abuse kavanaugh confirmation',
#  'abuse liberal',
#  'abuse liberal rinos',
#  'abuse metoo',
#  'abuse metoo really',
#  'abuse power',
#  'abuse power cause',
#  'abuse power completely',
#  'abuse power crap',
#  'abuse power darkest',
#  'abuse power spygate',
#  'abuse ramkrishnatearing',
#  'abuse ramkrishnatearing geeta',
#  'abuse right',
#  'abuse right deprive',
#  'abuse stop',
#  'abuse stop bias',
#  'abuse truth',
#  'abuse truth justice',
#  'abuse understand',
#  'abuse understand fucking',
#  'abuse unwary',
#  'abuse unwary weak',
#  'abuse vow',
#  'abuse vow celibacy',
#  'abuse young',
#  'abuse young men',
#  'abused african',
#  'abused african american',
#  'abused child',
#  'abused child silent',
#  'abused covering',
#  'abused disgusting',
#  'abused liberal',
#  'abused liberal weird',
#  'abused lying',
#  'abused mean',
#  'abused mean know',
#  'abused meet',
#  'abused meet animal',
#  'abused told',
#  'abused told op',
#  'abused woman',
#  'abused woman dont',
#  'abused woman maybe',
#  'abused year',
#  'abused year covered',
#  'abuser amp',
#  'abuser amp antifa',
#  'abuser better',
#  'abuser better hit',
#  'abuser criminal',
#  'abuser criminal kiss',
#  'abuser defend',
#  'abuser husband',
#  'abuser husband afraid',
#  'abuser kavanaugh',
#  'abuser kavanaugh family',
#  'abuser maybe',
#  'abuser pattern',
#  'abuser pattern ignoring',
#  'abuser progressive',
#  'abuser progressive pope',
#  'abuser project',
#  'abuser project look',
#  'abuser woman',
#  'abusing',
#  'abusing power',
#  'abusing power given',
#  'abusive animal',
#  'abusive animal stop',
#  'abusive arguing',
#  'abusive arguing left',
#  'abusive including',
#  'abusive including woman',
#  'abusive line',
#  'abusive line walk',
#  'abusive method',
#  'abusive method meant',
#  'abusuve',
#  'abusuve relationship',
#  'abusuve relationship messed',
#  'abysmal',
#  'abysmal little',
#  'abysmal little pharma',
#  'abysmal nd',
#  'abysmal nd half',
#  'abysmal st',
#  'abysmal st half',
#  'abyss',
#  'ac',
#  'ac commentary',
#  'ac commentary tweet',
#  'ac npr',
#  'ac npr pbsnews',
#  'aca',
#  'aca gun',
#  'aca gun control',
#  'aca hear',
#  'aca hear talking',
#  'aca reasonable',
#  'aca reasonable gun',
#  'academia',
#  'academia fingering',
#  'academia fingering kavanaugh',
#  'academic',
#  'academic basically',
#  'academic basically confirms',
#  'academic piece',
#  'academic piece linked',
#  'acc',
#  'acc man',
#  'acc man woman',
#  'accent',
#  'accent url',
#  'accept allegation',
#  'accept allegation blindly',
#  'accept allegation face',
#  'accept apology',
#  'accept apology excused',
#  'accept bad',
#  'accept bad ause',
#  'accept congresswoman',
#  'accept congresswoman stand',
#  'accept crumb',
#  'accept crumb fall',
#  'accept failure',
#  'accept failure president',
#  'accept government',
#  'accept government directive',
#  'accept hate',
#  'accept hate men',
#  'accept india',
#  'accept india definitely',
#  'accept offre',
#  'accept offre fear',
#  'accept racism',
#  'accept racism said',
#  'accept reality',
#  'accept responsible',
#  'accept responsible getting',
#  'accept result',
#  'accept result election',
#  'accept right',
#  'accept right youre',
#  'accept say',
#  'accept say thats',
#  'accept understand',
#  'accept understand easy',
#  'accept url',
#  'accept youre',
#  'accept youre better',
#  'acceptable bully',
#  'acceptable bully player',
#  'acceptable cardi',
#  'acceptable cardi nicki',
#  'acceptable conservative',
#  'acceptable conservative seated',
#  'acceptable liberal',
#  'acceptable liberal mean',
#  'acceptable maybe',
#  'acceptable maybe ok',
#  'acceptable positive',
#  'acceptable positive society',
#  'acceptance',
#  'acceptance tolerance',
#  'acceptance tolerance political',
#  'accepted',
#  'accepted antisemitism',
#  'accepted antisemitism definition',
#  'accepted loss',
#  'accepted loss grace',
#  'accepted sunblock',
#  'accepted sunblock wife',
#  'accepting',
#  'accepting compromise',
#  'accepting compromise voted',
#  'accepting cool',
#  'accepting cool folk',
#  'accepting imperical',
#  'accepting imperical evidence',
#  'accepting premise',
#  'accepting premise government',
#  'accepting thanking',
#  'accepting thanking advice',
#  'access assault',
#  'access assault weapon',
#  'access building',
#  'access building tory',
#  'access course',
#  'access course gun',
#  'access decent',
#  'access decent healthcare',
#  'access ended',
#  'access finance',
#  'access finance easier',
#  'access game',
#  'access game theyll',
#  'access gun',
#  'access gun control',
#  'access gun drop',
#  'access gun mentally',
#  'access place',
#  'access place metal',
#  'access safe',
#  'access safe abortion',
#  'access weapon',
#  'access weapon police',
#  'accessory',
#  'accessory hat',
#  'accessory hat deranged',
#  'accessory like',
#  'accessory like responsible',
#  'accident bloody',
#  'accident bloody awful',
#  'accident death',
#  'accident death grave',
#  'accident police',
#  'accident police believe',
#  'accident read',
#  'accident read url',
#  'accident state',
#  'accident state gone',
#  'accident toddler',
#  'accident toddler bad',
#  'accident vote',
#  'accident vote sewed',
#  'accident welcome',
#  'accident welcome tolerant',
#  'accidental',
#  'accidental injuried',
#  'accidental injuried snd',
#  'accidentally',
#  'accidentally bought',
#  'accidentally bought baby',
#  'accidentally left',
#  'accidentally left outside',
#  'accommodating',
#  'accomplish',
#  'accomplish goal',
#  'accomplish gun',
#  'accomplish gun control',
#  'accomplished',
#  'accomplished black',
#  'accomplished black men',
#  'accomplished libs',
#  'accomplished libs picturing',
#  'accomplished progressive',
#  'accomplished progressive actually',
#  'accomplished run',
#  'accomplished run mouth',
#  'accomplishment',
#  'accomplishment exceed',
#  'accomplishment exceed kerry',
#  'accomplishment fuk',
#  'accomplishment fuk liberal',
#  'accomplishment nasa',
#  'accomplishment nasa team',
#  'accomplishment worst',
#  'accomplishment worst president',
#  'accord',
#  'accord dropping',
#  'accord dropping supply',
#  'according bio',
#  'according bio christian',
#  'according bodyguard',
#  'according bodyguard room',
#  'according echr',
#  'according echr said',
#  'according gore',
#  'according gore hurricane',
#  'according instagram',
#  'according instagram post',
#  'according left',
#  'according liberal',
#  'according liberal amp',
#  'according liberal dare',
#  'according liberal yes',
#  'according plan',
#  'according plan remember',
#  'according reaction',
#  'according reaction got',
#  'according research',
#  'according research ended',
#  'according student',
#  'according student spoke',
#  'according went',
#  'according went school',
#  'according yr',
#  'according yr decides',
#  'accordingly',
#  'account antifa',
#  'account antifa member',
#  'account bit',
#  'account bit shit',
#  'account check',
#  'account check account',
#  'account check list',
#  'account chick',
#  'account chick list',
#  'account dont',
#  'account dont control',
#  'account fake',
#  'account fake dollar',
#  'account follow',
#  'account freedom',
#  'account freedom speech',
#  'account graph',
#  'account graph url',
#  'account harper',
#  'account harper satisfied',
#  'account hide',
#  'account hide true',
#  'account high',
#  'account high profile',
#  'account indicate',
#  'account indicate update',
#  'account involvement',
#  'account involvement leftist',
#  'account list',
#  'account list high',
#  'account list list',
#  'account minute',
#  'account minute amp',
#  'account mute',
#  'account mute maga',
#  'account oh',
#  'account paper',
#  'account paper good',
#  'account placed',
#  'account placed target',
#  'account police',
#  'account police brutality',
#  'account posting',
#  'account posting crap',
#  'account pushed',
#  'account pushed eve',
#  'account reason',
#  'account reason block',
#  'account smaller',
#  'account smaller vanish',
#  'account stuff',
#  'account stuff stranger',
#  'account suddenly',
#  'account suddenly want',
#  'account supporting',
#  'account supporting potus',
#  'account threat',
#  'account threat tax',
#  'account try',
#  'account try use',
#  'account url',
#  'account weird',
#  'account yall',
#  'account yall awesome',
#  'accountability',
#  'accountability turn',
#  'accountability turn unethical',
#  'accountability window',
#  'accountability window illegal',
#  'accountable action',
#  'accountable action need',
#  'accountable despicable',
#  'accountable despicable disgrace',
#  'accountable fail',
#  'accountable fail miserably',
#  'accountable hypocrisy',
#  'accountable hypocrisy moral',
#  'accountable lie',
#  'accountable pointing',
#  'accountable pointing finger',
#  'accountable refusal',
#  'accountable refusal enforce',
#  'accountable regardless',
#  'accountable regardless party',
#  'accountable responsibility',
#  'accountable say',
#  'accountable say contribute',
#  'accountable sign',
#  'accountable sign held',
#  'accountable vega',
#  'accountable vega shooting',
#  'accountable word',
#  'accountable word good',
#  'acct',
#  'acct called',
#  'acct called grok',
#  'accuracy',
#  'accurate',
#  'accurate metaphor',
#  'accurate metaphor nwo',
#  'accurate number',
#  'accurate number damned',
#  'accurate theory',
#  'accurate theory history',
#  'accurately',
#  'accurately predict',
#  'accurately predict action',
#  'accusation ambush',
#  'accusation ambush fact',
#  'accusation biased',
#  'accusation biased government',
#  'accusation confirm',
#  'accusation confirm kavanaugh',
#  'accusation conservative',
#  'accusation conservative seen',
#  'accusation credible',
#  'accusation credible evidence',
#  'accusation derail',
#  'accusation derail stop',
#  'accusation face',
#  'accusation face value',
#  'accusation facing',
#  'accusation facing legal',
#  'accusation fortunate',
#  'accusation fortunate live',
#  'accusation hurt',
#  'accusation hurt democrat',
#  'accusation incident',
#  'accusation incident year',
#  'accusation intelligence',
#  'accusation intelligence rest',
#  'accusation kajillions',
#  'accusation kajillions zombified',
#  'accusation kind',
#  'accusation kind far',
#  'accusation know',
#  'accusation know political',
#  'accusation known',
#  'accusation known child',
#  'accusation levied',
#  'accusation levied conservative',
#  'accusation liberal',
#  'accusation liberal mo',
#  'accusation libtarded',
#  'accusation libtarded trump',
#  'accusation obscures',
#  'accusation obscures selfcharacterization',
#  'accusation politically',
#  'accusation politically motivated',
#  'accusation postpone',
#  'accusation postpone vote',
#  'accusation potential',
#  'accusation potential assault',
#  'accusation prove',
#  'accusation prove theyre',
#  'accusation sexual',
#  'accusation sexual harassment',
#  'accusation sound',
#  'accusation sound cover',
#  'accusation supporting',
#  'accusation supporting time',
#  'accusation targeting',
#  'accusation targeting supreme',
#  'accusation true',
#  'accusation true liberal',
#  'accusation ulterior',
#  'accusation ulterior motif',
#  'accusation walkaway',
#  'accusation walkaway hypocrite',
#  'accusation write',
#  'accusation write book',
#  'accusation yr',
#  'accusation yr ago',
#  'accusationsboth',
#  'accusationsboth heard',
#  'accusationsboth heard private',
#  'accuse anybody',
#  'accuse anybody wrong',
#  'accuse chinese',
#  'accuse chinese spy',
#  'accuse conservative',
#  'accuse conservative wrong',
#  'accuse dems',
#  'accuse dems playbook',
#  'accuse king',
#  'accuse king tyrant',
#  'accuse like',
#  'accuse like amp',
#  'accuse person',
#  'accuse person sex',
#  'accused abuse',
#  'accused abuse hey',
#  'accused beating',
#  'accused beating wife',
#  'accused black',
#  'accused black men',
#  'accused clinton',
#  'accused clinton sexual',
#  'accused dems',
#  'accused failing',
#  'accused failing protect',
#  'accused going',
#  'accused going sc',
#  'accused government',
#  'accused government failing',
#  'accused husband',
#  'accused husband son',
#  'accused lacking',
#  'accused lacking empathy',
#  'accused man',
#  'accused man man',
#  'accused misconduct',
#  'accused probably',
#  'accused probably dems',
#  'accused rape',
#  'accused sexual',
#  'accused sexual assault',
#  'accused viciously',
#  'accused viciously attack',
#  'accused violencedomestic',
#  'accused violencedomestic violence',
#  'accused year',
#  'accused year ago',
#  'accuser accuser',
#  'accuser accuser stated',
#  'accuser actually',
#  'accuser actually need',
#  'accuser anymore',
#  'accuser anymore theyre',
#  'accuser based',
#  'accuser based soley',
#  'accuser bullied',
#  'accuser christine',
#  'accuser christine ford',
#  'accuser come',
#  'accuser come forward',
#  'accuser dems',
#  'accuser dems amid',
#  'accuser describes',
#  'accuser describes url',
#  'accuser didnt',
#  'accuser didnt time',
#  'accuser disappear',
#  'accuser double',
#  'accuser double standard',
#  'accuser enemy',
#  'accuser enemy people',
#  'accuser female',
#  'accuser female conservative',
#  'accuser hardcore',
#  'accuser hardcore left',
#  'accuser high',
#  'accuser high school',
#  'accuser ignored',
#  'accuser ill',
#  'accuser ill help',
#  'accuser incarcerated',
#  'accuser incarcerated baldfaced',
#  'accuser isnt',
#  ...]

# %%
clf_gram = LogisticRegression()

# %%
scores_gram = dict()

# %%
C = list(np.arange(0, 1, 0.05))

C = [float(i) for i in C]

C = C[1:]

C
# Out:
# [0.05,
#  0.1,
#  0.15000000000000002,
#  0.2,
#  0.25,
#  0.30000000000000004,
#  0.35000000000000003,
#  0.4,
#  0.45,
#  0.5,
#  0.55,
#  0.6000000000000001,
#  0.65,
#  0.7000000000000001,
#  0.75,
#  0.8,
#  0.8500000000000001,
#  0.9,
#  0.9500000000000001]

# %%
for i in C:
    clf_gram = LogisticRegression(C= i, max_iter=1000)
    clf_gram.fit(X_train_gram, y_train)
    scores_gram[i] = clf_gram.score(vect_gram.transform(X_test), y_test)
    
scores_gram
# Out:
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# {0.05: 0.6676737160120846,
#  0.1: 0.6676737160120846,
#  0.15000000000000002: 0.6676737160120846,
#  0.2: 0.6676737160120846,
#  0.25: 0.6676737160120846,
#  0.30000000000000004: 0.6676737160120846,
#  0.35000000000000003: 0.6676737160120846,
#  0.4: 0.66797583081571,
#  0.45: 0.66797583081571,
#  0.5: 0.66797583081571,
#  0.55: 0.66797583081571,
#  0.6000000000000001: 0.6682779456193354,
#  0.65: 0.6682779456193354,
#  0.7000000000000001: 0.6685800604229607,
#  0.75: 0.6688821752265861,
#  0.8: 0.6688821752265861,
#  0.8500000000000001: 0.6691842900302115,
#  0.9: 0.6694864048338368,
#  0.9500000000000001: 0.6697885196374622}

# %%
best_C = max(scores_gram, key=scores_gram.get)

print(best_C)
# Out:
# 0.9500000000000001

# %%
clf = LogisticRegression(C=best_C)

# %% [markdown]
# ### SSL Part

# %%
ssl1 = SelfTrainingClassifier(clf)

# %%
X_train_unlab_vect = vect_gram.fit_transform(X_train_unlab)

# %%
X_train_unlab_vect
# Out:
# <11243x173007 sparse matrix of type '<class 'numpy.float64'>'
# 	with 201270 stored elements in Compressed Sparse Row format>

# %%
ssl1.fit(X_train_unlab_vect, y_train_unlab)
# Out:
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SelfTrainingClassifier(base_estimator=LogisticRegression(C=0.9500000000000001))

# %%
ssl1.score(vect_gram.transform(X_test), y_test)
# Out:
# 0.6685800604229607

# %% [markdown]
# ### CBOW

# %%
#Sentence vectoriser - Average of sentence for each vector
def sent_vect(sent, model):
    sent = eval(sent)
    vec = np.zeros(32)
    num = 0
    for w in sent:
        try:
            temp_vec = model.wv.get_vector(w)
            #print(temp_vec)
            vec = np.add(vec, temp_vec)
            num += 1
        except:
            pass
        
    return vec / np.sqrt(vec.dot(vec))

# %%
X_train_cbow = pd.DataFrame(X_train.apply(sent_vect, model=cbow).sort_index())
X_train_cbow
# Out:
#                                                   tweet
# 0     [0.10371455167512132, -0.0026690812901859584, ...
# 1     [0.07306809735589292, 0.10742395934446738, 0.1...
# 2     [0.12152500412207404, 0.03987473932714874, 0.1...
# 3     [0.15234790567554005, 0.07549362942942803, 0.1...
# 4     [0.17659919052198297, 0.07970519122554563, 0.0...
# ...                                                 ...
# 9925  [0.1268052961219268, -0.15723430540881764, 0.1...
# 9926  [0.11029270031188039, 0.08434713848718038, 0.1...
# 9927  [0.07075947084083557, 0.020389900997694718, 0....
# 9928  [0.09825704417810942, -0.09855605385106399, 0....
# 9929  [0.0029189210899187015, -0.04699727707605283, ...
#
# [9930 rows x 1 columns]

# %%
X_train_cbow_unlab = pd.DataFrame(X_train_unlab.apply(sent_vect, model=cbow).sort_index())
X_train_cbow_unlab
# Out:
#                                                    tweet
# 0      [0.10371455167512132, -0.0026690812901859584, ...
# 1      [0.07306809735589292, 0.10742395934446738, 0.1...
# 2      [0.12152500412207404, 0.03987473932714874, 0.1...
# 3      [0.15234790567554005, 0.07549362942942803, 0.1...
# 4      [0.17659919052198297, 0.07970519122554563, 0.0...
# ...                                                  ...
# 11238  [0.08074036922904741, 0.023623614673037703, 0....
# 11239  [0.025660048931230296, -0.019617122927809535, ...
# 11240  [0.2108769863318312, 0.09056786766907235, 0.17...
# 11241  [0.07118914638028505, 0.01962914238976545, 0.2...
# 11242  [0.01858494496702415, -0.04847293713346957, 0....
#
# [11243 rows x 1 columns]

# %%
def convert_df(df):
    df_new = pd.DataFrame(columns=list(range(32)))
    for ind in df.index:
        #print(df.iloc[ind][0])
        df_test = pd.DataFrame([[k for k in df.iloc[ind][0]]], columns=list(range(32)))
        #print(df_test)
        df_new = df_new.append(df_test)
            
    return df_new

# %%
X_train_cbow = convert_df(X_train_cbow)
X_train_cbow
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.103715 -0.002669  0.153950  0.237088  0.150675  0.039473 -0.195056
# 0   0.073068  0.107424  0.124951  0.210843  0.136943  0.112223 -0.216901
# 0   0.121525  0.039875  0.136009  0.191058  0.122848  0.136994 -0.186814
# 0   0.152348  0.075494  0.128314  0.248046  0.166745  0.046800 -0.235776
# 0   0.176599  0.079705  0.089254  0.251721  0.144600  0.004873 -0.232831
# ..       ...       ...       ...       ...       ...       ...       ...
# 0   0.126805 -0.157234  0.147893  0.072082  0.165811  0.132364 -0.074539
# 0   0.110293  0.084347  0.113860  0.235922  0.140378  0.093828 -0.228333
# 0   0.070759  0.020390  0.284672  0.151575  0.171471  0.144294 -0.215269
# 0   0.098257 -0.098556  0.137465  0.132955  0.144681  0.106873 -0.107304
# 0   0.002919 -0.046997  0.220562  0.158752  0.102401  0.102465 -0.193851
#
#           7         8         9   ...        22        23        24        25  \
# 0  -0.123852 -0.135551 -0.243535  ... -0.040841  0.295382 -0.165185 -0.095019
# 0  -0.158670 -0.104263 -0.230354  ... -0.075750  0.237339 -0.120083 -0.047526
# 0  -0.126776 -0.084429 -0.229106  ... -0.112223  0.311797 -0.094857 -0.041932
# 0  -0.084590 -0.143277 -0.183683  ... -0.076028  0.267752 -0.061788 -0.067676
# 0  -0.091239 -0.153556 -0.126065  ... -0.099872  0.273970 -0.048746 -0.073946
# ..       ...       ...       ...  ...       ...       ...       ...       ...
#
# 3307 -0.033458 -0.138051  0.238075 -0.165277 -0.309097 -0.020612 -0.055424
# 3308 -0.056029 -0.131267  0.286019 -0.156764 -0.355000  0.022938 -0.074697
# 3309  0.028883 -0.205290  0.210374 -0.153853 -0.321342  0.033644 -0.087551
#
# [3310 rows x 32 columns]

# %% [markdown]
# ## SkipGram

# %%
X_train_sg = pd.DataFrame(X_train.apply(sent_vect, model=skg).sort_index())
X_train_sg
# Out:
#                                                   tweet
# 0     [0.1385263343767096, 0.019514727808935924, 0.1...
# 1     [-0.08006676582537567, 0.14220038026696025, 0....
# 2     [0.12745751758561877, 0.04590809994137651, 0.1...
# 3     [0.148907211855406, 0.045357729192608165, 0.14...
# 4     [0.16997259111404198, 0.02170235144521857, 0.1...
# ...                                                 ...
# 9925  [0.12765205081760966, -0.08407392444930872, 0....
# 9926  [0.0927742904159179, 0.10098635879091483, 0.18...
# 9927  [0.03132195112290745, -0.008785520980705315, 0...
# 9928  [0.12725105628106392, 0.0018205805003424804, 0...
# 9929  [-0.02001318080064111, -0.08916336317861015, 0...
#
# [9930 rows x 1 columns]

# %%
X_train_sg = convert_df(X_train_sg)
X_train_sg
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.138526  0.019515  0.166428  0.216446  0.138855 -0.055935 -0.304432
# 0  -0.080067  0.142200  0.089483  0.227434  0.094180 -0.101437 -0.283416
# 0   0.127458  0.045908  0.189589  0.198233  0.063745  0.024450 -0.278034
# 0   0.148907  0.045358  0.144209  0.225686  0.135249 -0.076277 -0.290739
# 0   0.169973  0.021702  0.155327  0.146038  0.122168 -0.014653 -0.339412
# ..       ...       ...       ...       ...       ...       ...       ...
# 0   0.127652 -0.084074  0.174262  0.150152  0.113654  0.040448 -0.155156
# 0   0.092774  0.100986  0.181881  0.224044  0.066471 -0.086826 -0.303038
# 0   0.031322 -0.008786  0.191570 -0.038806  0.202409 -0.133450 -0.266983
# 0   0.127251  0.001821  0.158656  0.194201  0.095285  0.002959 -0.245097
# 0  -0.020013 -0.089163  0.282781  0.136771  0.046512  0.004903 -0.352863
#
#           7         8         9   ...        22        23        24        25  \
# 0  -0.105380 -0.253149 -0.145664  ...  0.044108  0.247816 -0.014868 -0.132315
# 0  -0.271291 -0.158280 -0.155238  ...  0.004326  0.131149  0.010339 -0.120501
# 0  -0.142304 -0.173098 -0.198859  ... -0.021820  0.279669 -0.020304 -0.031698
# 0  -0.070622 -0.252579 -0.185700  ... -0.029599  0.221062  0.045011 -0.093727
# 0  -0.174432 -0.236059 -0.159709  ... -0.032499  0.235318 -0.047131 -0.052464
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 0  -0.126418 -0.140530 -0.202361  ...  0.007135  0.391230  0.026749 -0.054714
# 0  -0.138654 -0.207029 -0.215850  ...  0.057712  0.176765  0.016488 -0.034340
# 0  -0.178629 -0.201017 -0.175390  ... -0.000081 -0.004056  0.007496  0.073737
# 0  -0.140138 -0.183438 -0.190055  ...  0.017772  0.333084 -0.034208 -0.092449
# 0  -0.125783 -0.192457 -0.294699  ...  0.087864  0.136034 -0.163224  0.036919
#
#           26        27        28        29        30        31
# 4    -0.052464 -0.139022  0.347737 -0.113199 -0.292628 -0.094603 -0.110658
# ...        ...       ...       ...       ...       ...       ...       ...
# 9925 -0.054714 -0.156879  0.304719 -0.058767 -0.119983 -0.059841 -0.133095
# 9926 -0.034340 -0.111519  0.332314 -0.140747 -0.275698  0.007117 -0.164574
# 9927  0.073737 -0.116133  0.245116 -0.093048 -0.435757  0.029019 -0.049457
# 9928 -0.092449 -0.104142  0.299297 -0.093698 -0.247580 -0.028847 -0.121487
# 9929  0.036919 -0.083115  0.208763 -0.114716 -0.172448 -0.073597  0.035051
#
# [9930 rows x 32 columns]

# %%
X_test_sg = pd.DataFrame(X_test.apply(sent_vect, model=skg).sort_index())
X_test_sg
# Out:
#                                                   tweet
# 0     [0.18875114073130442, 0.08504719451227362, 0.1...
# 1     [0.05188641031166471, 0.013299822209388771, 0....
# 2     [0.13536494020923442, 0.0696965417494669, 0.18...
# 3     [0.0894113589072249, 0.07385733091233998, 0.25...
# 4     [0.0072756068506350455, -0.026303194567468446,...
# ...                                                 ...
# 3305  [0.0020736232913729324, 0.02083250365649504, 0...
# 3306  [0.08188323487742742, 0.0770203957617591, 0.16...
# 3307  [0.09181048100092186, 0.07948521787336231, 0.2...
# 3308  [0.1345131574072599, 0.07300238704530669, 0.16...
# 3309  [0.06369042695304587, 0.05278405185722749, 0.2...
#
# [3310 rows x 1 columns]

# %%
X_test_sg = convert_df(X_test_sg)
X_test_sg
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.188751  0.085047  0.196057  0.239633  0.008141 -0.116937 -0.242850
# 0   0.051886  0.013300  0.199116  0.219596  0.103695 -0.123744 -0.340428
# 0   0.135365  0.069697  0.184692  0.214738  0.074391 -0.009202 -0.339338
# 0   0.089411  0.073857  0.254223  0.236446  0.032962  0.035375 -0.299110
# 0   0.007276 -0.026303  0.310812  0.187619 -0.046498  0.005140 -0.335359
# ..       ...       ...       ...       ...       ...       ...       ...
# 0   0.002074  0.020833  0.233672  0.193114  0.168599 -0.062129 -0.267139
# 0   0.081883  0.077020  0.163880  0.256423  0.065097 -0.064530 -0.311738
# 0   0.091810  0.079485  0.261488  0.198871 -0.054910  0.020760 -0.343560
# 0   0.134513  0.073002  0.160120  0.251022  0.049659 -0.014722 -0.296490
# 0   0.063690  0.052784  0.211363  0.138811  0.155421 -0.026346 -0.321467
#
#           7         8         9   ...        22        23        24        25  \
# 0  -0.122347 -0.285015 -0.094142  ...  0.011010  0.237834 -0.019016 -0.185786
# 0  -0.031157 -0.307546 -0.133739  ...  0.075871  0.235019 -0.106251 -0.098781
# 0  -0.087252 -0.191786 -0.150359  ...  0.005173  0.298982 -0.004578 -0.102171
# 0  -0.123629 -0.179272 -0.194257  ...  0.004952  0.270153 -0.033486 -0.031937
# 0  -0.163222 -0.214707 -0.262072  ...  0.128120  0.193110 -0.144317 -0.011589
# ..       ...       ...       ...  ...       ...       ...       ...       ...
#
# 1    -0.098781 -0.133301  0.343419 -0.004178 -0.283949 -0.063387 -0.102155
# 2    -0.102171 -0.097365  0.357899 -0.110279 -0.246588 -0.044963 -0.097967
# 3    -0.031937 -0.097374  0.297543 -0.142485 -0.225717 -0.026829 -0.099505
# 4    -0.011589 -0.153744  0.206998 -0.053822 -0.196023 -0.069643 -0.040368
# ...        ...       ...       ...       ...       ...       ...       ...
# 3305 -0.082573 -0.176128  0.228615 -0.149781 -0.174326  0.015865 -0.178080
# 3306 -0.105840 -0.102386  0.373417 -0.178432 -0.271525 -0.022581 -0.139250
# 3307 -0.043398 -0.087369  0.302408 -0.134575 -0.220996 -0.000280 -0.121065
# 3308 -0.089034 -0.060303  0.403693 -0.102535 -0.316395 -0.016215 -0.129192
# 3309 -0.004101 -0.093097  0.314690 -0.133337 -0.419804  0.029285 -0.087705
#
# [3310 rows x 32 columns]

# %%
X_train_sg_unlab = pd.DataFrame(X_train_unlab.apply(sent_vect, model=skg).sort_index())

# %%
X_train_sg_unlab
# Out:
#                                                    tweet
# 0      [0.1385263343767096, 0.019514727808935924, 0.1...
# 1      [-0.08006676582537567, 0.14220038026696025, 0....
# 2      [0.12745751758561877, 0.04590809994137651, 0.1...
# 3      [0.148907211855406, 0.045357729192608165, 0.14...
# 4      [0.16997259111404198, 0.02170235144521857, 0.1...
# ...                                                  ...
# 11238  [0.0877175979810819, -0.024054452757491043, 0....
# 11239  [0.08084574607521673, 0.0591042073947315, 0.25...
# 11240  [0.2187457234647719, 0.07468842552941364, 0.18...
# 11241  [0.11668345874892752, 0.042231378233500066, 0....
# 11242  [0.06426341446634914, -0.01621600174754292, 0....
#
# [11243 rows x 1 columns]

# %%
X_train_sg_unlab = convert_df(X_train_sg_unlab)
X_train_sg_unlab
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.138526  0.019515  0.166428  0.216446  0.138855 -0.055935 -0.304432
# 0  -0.080067  0.142200  0.089483  0.227434  0.094180 -0.101437 -0.283416
# 0   0.127458  0.045908  0.189589  0.198233  0.063745  0.024450 -0.278034
# 0   0.148907  0.045358  0.144209  0.225686  0.135249 -0.076277 -0.290739
# 0   0.169973  0.021702  0.155327  0.146038  0.122168 -0.014653 -0.339412
# ..       ...       ...       ...       ...       ...       ...       ...
# 0   0.087718 -0.024054  0.203854  0.249087  0.105207  0.015620 -0.366716
# 0   0.080846  0.059104  0.251195  0.231769  0.065487  0.024094 -0.330607
# 0   0.218746  0.074688  0.188355  0.317208  0.010325 -0.045743 -0.236095
# 0   0.116683  0.042231  0.265538  0.269076  0.120013  0.002366 -0.314538
# 0   0.064263 -0.016216  0.281401  0.166621 -0.038377  0.050999 -0.290212
#
#           7         8         9   ...        22        23        24        25  \
# 0  -0.105380 -0.253149 -0.145664  ...  0.044108  0.247816 -0.014868 -0.132315
# 0  -0.271291 -0.158280 -0.155238  ...  0.004326  0.131149  0.010339 -0.120501
# 0  -0.142304 -0.173098 -0.198859  ... -0.021820  0.279669 -0.020304 -0.031698
# 0  -0.070622 -0.252579 -0.185700  ... -0.029599  0.221062  0.045011 -0.093727
# 0  -0.174432 -0.236059 -0.159709  ... -0.032499  0.235318 -0.047131 -0.052464
# ..       ...       ...       ...  ...       ...       ...       ...       ...
#
# 11239 -0.111610 -0.183350 -0.205393  ... -0.017894  0.265083 -0.034696
# 11240 -0.098206 -0.244948 -0.095663  ...  0.024123  0.211924 -0.037041
# 11241 -0.080609 -0.155711 -0.204829  ...  0.012902  0.092975 -0.059500
# 11242 -0.134390 -0.183265 -0.235979  ...  0.060104  0.248274 -0.139113
#
#              25        26        27        28        29        30        31
# 0     -0.132315 -0.070216  0.392828 -0.073529 -0.348592 -0.013779 -0.117852
# 1     -0.120501 -0.036472  0.269971 -0.075283 -0.347463  0.135049 -0.180314
# 2     -0.031698 -0.058815  0.325629 -0.146991 -0.255908 -0.032594 -0.118372
# 3     -0.093727 -0.040805  0.419570 -0.083075 -0.267348  0.001566 -0.162518
# 4     -0.052464 -0.139022  0.347737 -0.113199 -0.292628 -0.094603 -0.110658
# ...         ...       ...       ...       ...       ...       ...       ...
# 11238 -0.066157 -0.042412  0.340199 -0.082934 -0.191944 -0.007212 -0.009766
# 11239 -0.023888 -0.147687  0.311157 -0.120094 -0.232114 -0.047364 -0.107032
# 11240 -0.186651 -0.114775  0.412285 -0.036984 -0.267000 -0.027948 -0.129779
# 11241 -0.065757 -0.086546  0.426074 -0.095765 -0.276681 -0.006456 -0.167826
# 11242 -0.008807 -0.100699  0.237453 -0.108703 -0.179127 -0.026443 -0.134277
#
# [11243 rows x 32 columns]

# %% [markdown]
# ## Training SVM (Supervised only, TF-IDF)

# %%
clf = SVC()

# %%
params = {'kernel': ['linear', 'rbf', 'sigmoid'], 'C': [0.001, 0.05, 0.01, 0.1, 1, 5, 10, 100], 'gamma': [0.01, 0.1, 1, 5, 10, 100]}

# %%
clf.fit(X_train_tf, y_train)
# Out:
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SVC()

# %%
clf.score(X_test_tf, y_test)
# Out:
# 0.66797583081571

# %%
gsc = GridSearchCV(clf, param_grid=params, n_jobs=-1)

# %%
grid_result = gsc.fit(X_train_tf, y_train)
# Out:
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
best_params = grid_result.best_params_
best_params
# Out:
# {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}

# %%
grid_result.best_score_
# Out:
# 0.6715005035246727

# %%
clf = SVC(C=best_params['C'], gamma=best_params['gamma'], kernel=best_params['kernel'], probability = True)
clf
# Out:
# SVC(C=1, gamma=0.01, kernel='linear', probability=True)

# %% [markdown]
# ## Train SVM (Self-Training)

# %%
self_training_model = SelfTrainingClassifier(clf)

# %%
X_train_tf_unlab = tfidf.transform(X_train_unlab.sort_index())
print(X_train_tf_unlab)
# Out:
#   (1, 103722)	1.0
#   (2, 101960)	0.21961777901669413
#   (2, 101959)	0.21961777901669413
#   (2, 91080)	0.21961777901669413
#   (2, 91078)	0.19845815360331623
#   (2, 83676)	0.21961777901669413
#   (2, 83675)	0.21961777901669413
#   (2, 65724)	0.21961777901669413
#   (2, 65723)	0.21961777901669413
#   (2, 55820)	0.21961777901669413
#   (2, 55819)	0.21961777901669413
#   (2, 54901)	0.21961777901669413
#   (2, 54900)	0.21961777901669413
#   (2, 50963)	0.21961777901669413
#   (2, 50962)	0.21961777901669413
#   (2, 50961)	0.21961777901669413
#   (2, 35384)	0.21961777901669413
#   (2, 35383)	0.21961777901669413
#   (2, 35382)	0.21025449560967407
#   (2, 22432)	0.21961777901669413
#   (2, 11342)	0.21961777901669413
#   (2, 11341)	0.21961777901669413
#   (3, 129226)	0.18324023010631316
#   (3, 129225)	0.18324023010631316
#   (3, 109123)	0.18324023010631316
#   :	:
#   (11232, 38289)	0.42422637470878855
#   (11232, 37967)	0.457576408013781
#   (11232, 34618)	0.457576408013781
#   (11232, 12423)	0.457576408013781
#   (11233, 45696)	0.5482588539099604
#   (11233, 38958)	0.5913595476143667
#   (11233, 38957)	0.5913595476143667
#   (11234, 9527)	1.0
#   (11235, 150723)	0.6798777346234774
#   (11235, 133436)	0.7333254843268767
#   (11236, 125089)	0.5687835506831989
#   (11236, 82674)	0.5687835506831989
#   (11236, 69988)	0.5941132425257208
#   (11237, 92468)	0.43176518300780736
#   (11237, 8957)	0.9019860457580454
#   (11238, 87267)	1.0
#   (11239, 141572)	0.5622408795155741
#   (11239, 110563)	0.6064407529207676
#   (11239, 86735)	0.5622408795155741
#   (11240, 80877)	0.7071067811865476
#   (11240, 38154)	0.7071067811865476
#   (11241, 130588)	1.0
#   (11242, 69689)	0.5773502691896257
#   (11242, 35156)	0.5773502691896257
#   (11242, 25641)	0.5773502691896257

# %%
self_training_model.fit(X_train_tf_unlab, y_train_unlab)
# Out:
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SelfTrainingClassifier(base_estimator=SVC(C=1, gamma=0.01, kernel='linear',
#                                           probability=True))

# %%
self_training_model.score(X_test_tf, y_test)
# Out:
# 0.670392749244713

# %% [markdown]
# ## Train SVM (CBOW W2V)

# %%
clf_w = SVC()

# %%
clf_w.fit(X_train_cbow, y_train)
# Out:
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SVC()

# %%
clf_w.score(X_test_cbow, y_test)
# Out:
# 0.6676737160120846

# %%
gsc_w2v = GridSearchCV(clf_w, param_grid=params, n_jobs=-1)

# %%
grid_res_w2v = gsc_w2v.fit(X_train_cbow, y_train)
# Out:
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
best_params_w2v = grid_res_w2v.best_params_
best_params_w2v
# Out:
# {'C': 100, 'gamma': 5, 'kernel': 'rbf'}

# %%
grid_res_w2v.best_score_
# Out:
# 0.6848942598187311

# %%
clf_w = SVC(C=best_params_w2v['C'], gamma=best_params_w2v['gamma'], kernel=best_params_w2v['kernel'], probability = True)
clf_w
# Out:
# SVC(C=100, gamma=5, probability=True)

# %% [markdown]
# ## W2V Self-Training

# %%
ssl_w2v = SelfTrainingClassifier(clf_w)

# %%
ssl_w2v.fit(X_train_cbow_unlab, y_train_unlab)
# Out:
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SelfTrainingClassifier(base_estimator=SVC(C=100, gamma=5, probability=True))

# %%
ssl_w2v.score(X_test_cbow, y_test)
# Out:
# 0.6779456193353475

# %% [markdown]
# ## Train SVM (SKG W2V)

# %%
clf_skg = SVC()

# %%
clf_skg.fit(X_train_sg, y_train)
# Out:
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SVC()

# %%
clf_skg.score(X_test_sg, y_test)
# Out:
# 0.6731117824773414

# %%
gsc_w2v_sg = GridSearchCV(clf_w, param_grid=params, n_jobs=-1)

# %%
grid_res_w2v_sg = gsc_w2v_sg.fit(X_train_cbow, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-95-16c99e9335d3> in <module>
# ----> 1 grid_res_w2v_sg = gsc_w2v_sg.fit(X_train_cbow, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1286     def _run_search(self, evaluate_candidates):
#    1287         """Search all candidates in param_grid"""
# -> 1288         evaluate_candidates(ParameterGrid(self.param_grid))
#    1289
#    1290
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     793                               n_splits, n_candidates, n_candidates * n_splits))
#     794
# --> 795                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     796                                                        X, y,
#     797                                                        train=train, test=test,
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~\anaconda3\lib\concurrent\futures\_base.py in result(self, timeout)
#     432                 return self.__get_result()
#     433
# --> 434             self._condition.wait(timeout)
#     435
#     436             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~\anaconda3\lib\threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
best_params_w2v_sg = grid_res_w2v_sg.best_params_
best_params_w2v_sg

# %%
grid_res_w2v_sg.best_score_

# %%
clf_skf = SVC(C=best_params_w2v_sg['C'], gamma=best_params_w2v_sg['gamma'], kernel=best_params_w2v_sg['kernel'], probability = True)
clf_skg

# %% [markdown]
#  ## Logistic Regression

# %% [markdown]
# ### TF-IDF

# %%
clf = LogisticRegression()

# %%
C = list(np.arange(0, 1, 0.05))

C = [float(i) for i in C]

C = C[1:]

C
# Out:
# [0.05,
#  0.1,
#  0.15000000000000002,
#  0.2,
#  0.25,
#  0.30000000000000004,
#  0.35000000000000003,
#  0.4,
#  0.45,
#  0.5,
#  0.55,
#  0.6000000000000001,
#  0.65,
#  0.7000000000000001,
#  0.75,
#  0.8,
#  0.8500000000000001,
#  0.9,
#  0.9500000000000001]

# %%
scores = dict()

# %%
for i in C:
    clf = LogisticRegression(C= i, max_iter=1000)
    clf.fit(X_train_tf, y_train)
    scores[i] = clf.score(X_test_tf, y_test)
    
scores
# Out:
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# {0.05: 0.6676737160120846,
#  0.1: 0.6676737160120846,
#  0.15000000000000002: 0.6676737160120846,
#  0.2: 0.6676737160120846,
#  0.25: 0.6676737160120846,
#  0.30000000000000004: 0.6676737160120846,
#  0.35000000000000003: 0.6676737160120846,
#  0.4: 0.6676737160120846,
#  0.45: 0.6676737160120846,
#  0.5: 0.6676737160120846,
#  0.55: 0.6676737160120846,
#  0.6000000000000001: 0.66797583081571,
#  0.65: 0.66797583081571,
#  0.7000000000000001: 0.6685800604229607,
#  0.75: 0.6685800604229607,
#  0.8: 0.6685800604229607,
#  0.8500000000000001: 0.6685800604229607,
#  0.9: 0.6691842900302115,
#  0.9500000000000001: 0.6691842900302115}

# %%
best_C = max(scores, key=scores.get)

print(best_C)
# Out:
# 0.9

# %%
clf = LogisticRegression(C=best_C)

# %%
clf.fit(X_train_tf, y_train)
# Out:
# C:\Users\suhas\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# LogisticRegression(C=0.9)

# %%
clf.score(X_test_tf, y_test)
# Out:
# 0.6691842900302115
