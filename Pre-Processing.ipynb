# %%
import pandas as pd
import nltk
import string
import re
from nltk.corpus import wordnet

# %% [markdown]
# ## Importing

# %%
df = pd.read_csv(r"C:\Users\suhas\Documents\College Projects\SSL-Offensive-Lang-Detection-Social-Media\OLIDv1.0\olid-training-v1.0.tsv", sep="\t")

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426  @USER She should ask a few native Americans wh...       OFF
# 1      90194  @USER @USER Go home you’re drunk!!! @USER #MAG...       OFF
# 2      16820  Amazon is investigating Chinese employees who ...       NOT
# 3      62688  @USER Someone should'veTaken" this piece of sh...       OFF
# 4      43605  @USER @USER Obama wanted liberals &amp; illega...       NOT
# ...      ...                                                ...       ...
# 13235  95338  @USER Sometimes I get strong vibes from people...       OFF
# 13236  67210  Benidorm ✅  Creamfields ✅  Maga ✅   Not too sh...       NOT
# 13237  82921  @USER And why report this garbage.  We don't g...       OFF
# 13238  27429                                        @USER Pussy       OFF
# 13239  46552  #Spanishrevenge vs. #justice #HumanRights and ...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %% [markdown]
# ## Twitter Pre-Processing

# %%
df['tweet'] = df['tweet'].str.replace('@USER','')

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426   She should ask a few native Americans what th...       OFF
# 1      90194    Go home you’re drunk!!!  #MAGA #Trump2020 👊🇺...       OFF
# 2      16820  Amazon is investigating Chinese employees who ...       NOT
# 3      62688   Someone should'veTaken" this piece of shit to...       OFF
# 4      43605    Obama wanted liberals &amp; illegals to move...       NOT
# ...      ...                                                ...       ...
# 13235  95338   Sometimes I get strong vibes from people and ...       OFF
# 13236  67210  Benidorm ✅  Creamfields ✅  Maga ✅   Not too sh...       NOT
# 13237  82921   And why report this garbage.  We don't give a...       OFF
# 13238  27429                                              Pussy       OFF
# 13239  46552  #Spanishrevenge vs. #justice #HumanRights and ...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %%
# Removing hyperlinks
def hyperlink(tweet):
    return re.sub(r'https?:\/\/.*[\r\n]*', '', tweet)

# %%
df['tweet'] = df['tweet'].apply(hyperlink)

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426   She should ask a few native Americans what th...       OFF
# 1      90194    Go home you’re drunk!!!  #MAGA #Trump2020 👊🇺...       OFF
# 2      16820  Amazon is investigating Chinese employees who ...       NOT
# 3      62688   Someone should'veTaken" this piece of shit to...       OFF
# 4      43605    Obama wanted liberals &amp; illegals to move...       NOT
# ...      ...                                                ...       ...
# 13235  95338   Sometimes I get strong vibes from people and ...       OFF
# 13236  67210  Benidorm ✅  Creamfields ✅  Maga ✅   Not too sh...       NOT
# 13237  82921   And why report this garbage.  We don't give a...       OFF
# 13238  27429                                              Pussy       OFF
# 13239  46552  #Spanishrevenge vs. #justice #HumanRights and ...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %%
# Removing retweets
def retweets(tweet):
    return re.sub(r'^RT[\s]+', '', tweet)

# %%
df['tweet'] = df['tweet'].apply(retweets)

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426   She should ask a few native Americans what th...       OFF
# 1      90194    Go home you’re drunk!!!  #MAGA #Trump2020 👊🇺...       OFF
# 2      16820  Amazon is investigating Chinese employees who ...       NOT
# 3      62688   Someone should'veTaken" this piece of shit to...       OFF
# 4      43605    Obama wanted liberals &amp; illegals to move...       NOT
# ...      ...                                                ...       ...
# 13235  95338   Sometimes I get strong vibes from people and ...       OFF
# 13236  67210  Benidorm ✅  Creamfields ✅  Maga ✅   Not too sh...       NOT
# 13237  82921   And why report this garbage.  We don't give a...       OFF
# 13238  27429                                              Pussy       OFF
# 13239  46552  #Spanishrevenge vs. #justice #HumanRights and ...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %%
def split_hashtag(tweet):
    return re.sub(r'#', '', tweet)

# %%
df['tweet'] = df['tweet'].apply(split_hashtag)

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426   She should ask a few native Americans what th...       OFF
# 1      90194    Go home you’re drunk!!!  MAGA Trump2020 👊🇺🇸👊...       OFF
# 2      16820  Amazon is investigating Chinese employees who ...       NOT
# 3      62688   Someone should'veTaken" this piece of shit to...       OFF
# 4      43605    Obama wanted liberals &amp; illegals to move...       NOT
# ...      ...                                                ...       ...
# 13235  95338   Sometimes I get strong vibes from people and ...       OFF
# 13236  67210  Benidorm ✅  Creamfields ✅  Maga ✅   Not too sh...       NOT
# 13237  82921   And why report this garbage.  We don't give a...       OFF
# 13238  27429                                              Pussy       OFF
# 13239  46552  Spanishrevenge vs. justice HumanRights and Fre...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %%
# Splitting joined words
def join_words(tweet):
    return re.sub(r"([a-z\.!?])([A-Z])", r"\1 \2", tweet)

# %%
df['tweet'] = df['tweet'].apply(join_words)

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426   She should ask a few native Americans what th...       OFF
# 1      90194    Go home you’re drunk!!!  MAGA Trump2020 👊🇺🇸👊...       OFF
# 2      16820  Amazon is investigating Chinese employees who ...       NOT
# 3      62688   Someone should've Taken" this piece of shit t...       OFF
# 4      43605    Obama wanted liberals &amp; illegals to move...       NOT
# ...      ...                                                ...       ...
# 13235  95338   Sometimes I get strong vibes from people and ...       OFF
# 13236  67210  Benidorm ✅  Creamfields ✅  Maga ✅   Not too sh...       NOT
# 13237  82921   And why report this garbage.  We don't give a...       OFF
# 13238  27429                                              Pussy       OFF
# 13239  46552  Spanishrevenge vs. justice Human Rights and Fr...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %% [markdown]
# ## Removing Numbers

# %%
df['tweet'] = df['tweet'].replace('\d+', '', regex=True)

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426   She should ask a few native Americans what th...       OFF
# 1      90194       Go home you’re drunk!!!  MAGA Trump 👊🇺🇸👊 URL       OFF
# 2      16820  Amazon is investigating Chinese employees who ...       NOT
# 3      62688   Someone should've Taken" this piece of shit t...       OFF
# 4      43605    Obama wanted liberals &amp; illegals to move...       NOT
# ...      ...                                                ...       ...
# 13235  95338   Sometimes I get strong vibes from people and ...       OFF
# 13236  67210  Benidorm ✅  Creamfields ✅  Maga ✅   Not too sh...       NOT
# 13237  82921   And why report this garbage.  We don't give a...       OFF
# 13238  27429                                              Pussy       OFF
# 13239  46552  Spanishrevenge vs. justice Human Rights and Fr...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %% [markdown]
# ## Removing Punctuation

# %%
df['tweet'] = df['tweet'].str.replace('[{}]'.format(string.punctuation), '')
# Out:
# C:\Users\suhas\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426   She should ask a few native Americans what th...       OFF
# 1      90194          Go home you’re drunk  MAGA Trump 👊🇺🇸👊 URL       OFF
# 2      16820  Amazon is investigating Chinese employees who ...       NOT
# 3      62688   Someone shouldve Taken this piece of shit to ...       OFF
# 4      43605    Obama wanted liberals amp illegals to move i...       NOT
# ...      ...                                                ...       ...
# 13235  95338   Sometimes I get strong vibes from people and ...       OFF
# 13236  67210  Benidorm ✅  Creamfields ✅  Maga ✅   Not too sh...       NOT
# 13237  82921   And why report this garbage  We dont give a crap       OFF
# 13238  27429                                              Pussy       OFF
# 13239  46552  Spanishrevenge vs justice Human Rights and Fre...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %% [markdown]
# ## Removing Whitespaces

# %%
df['tweet'] = df['tweet'].str.strip()

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426  She should ask a few native Americans what the...       OFF
# 1      90194          Go home you’re drunk  MAGA Trump 👊🇺🇸👊 URL       OFF
# 2      16820  Amazon is investigating Chinese employees who ...       NOT
# 3      62688  Someone shouldve Taken this piece of shit to a...       OFF
# 4      43605  Obama wanted liberals amp illegals to move int...       NOT
# ...      ...                                                ...       ...
# 13235  95338  Sometimes I get strong vibes from people and t...       OFF
# 13236  67210  Benidorm ✅  Creamfields ✅  Maga ✅   Not too sh...       NOT
# 13237  82921   And why report this garbage  We dont give a crap       OFF
# 13238  27429                                              Pussy       OFF
# 13239  46552  Spanishrevenge vs justice Human Rights and Fre...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %% [markdown]
# ## Converting to lowercase

# %%
df['tweet'] = df['tweet'].str.lower()

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426  she should ask a few native americans what the...       OFF
# 1      90194          go home you’re drunk  maga trump 👊🇺🇸👊 url       OFF
# 2      16820  amazon is investigating chinese employees who ...       NOT
# 3      62688  someone shouldve taken this piece of shit to a...       OFF
# 4      43605  obama wanted liberals amp illegals to move int...       NOT
# ...      ...                                                ...       ...
# 13235  95338  sometimes i get strong vibes from people and t...       OFF
# 13236  67210  benidorm ✅  creamfields ✅  maga ✅   not too sh...       NOT
# 13237  82921   and why report this garbage  we dont give a crap       OFF
# 13238  27429                                              pussy       OFF
# 13239  46552  spanishrevenge vs justice human rights and fre...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %% [markdown]
# ## Removing Stop Words

# %%
from nltk.corpus import stopwords  
from nltk.tokenize import TweetTokenizer 
tokenizer = TweetTokenizer(preserve_case=True, strip_handles=True, reduce_len=True)

# %%
def token(tweet):
    return tokenizer.tokenize(tweet)

# %%
df['tweet'] = df['tweet'].apply(token)

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426  [she, should, ask, a, few, native, americans, ...       OFF
# 1      90194  [go, home, you, ’, re, drunk, maga, trump, 👊, ...       OFF
# 2      16820  [amazon, is, investigating, chinese, employees...       NOT
# 3      62688  [someone, shouldve, taken, this, piece, of, sh...       OFF
# 4      43605  [obama, wanted, liberals, amp, illegals, to, m...       NOT
# ...      ...                                                ...       ...
# 13235  95338  [sometimes, i, get, strong, vibes, from, peopl...       OFF
# 13236  67210  [benidorm, ✅, creamfields, ✅, maga, ✅, not, to...       NOT
# 13237  82921  [and, why, report, this, garbage, we, dont, gi...       OFF
# 13238  27429                                            [pussy]       OFF
# 13239  46552  [spanishrevenge, vs, justice, human, rights, a...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %%
stop_words = set(stopwords.words('english'))

# %%
def remove(tweet):
    return [i for i in tweet if i not in stop_words]

# %%
df['tweet'] = df['tweet'].apply(remove)

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426                     [ask, native, americans, take]       OFF
# 1      90194  [go, home, ’, drunk, maga, trump, 👊, 🇺, 🇸, 👊, ...       OFF
# 2      16820  [amazon, investigating, chinese, employees, se...       NOT
# 3      62688  [someone, shouldve, taken, piece, shit, volcan...       OFF
# 4      43605  [obama, wanted, liberals, amp, illegals, move,...       NOT
# ...      ...                                                ...       ...
# 13235  95338  [sometimes, get, strong, vibes, people, man, ’...       OFF
# 13236  67210  [benidorm, ✅, creamfields, ✅, maga, ✅, shabby,...       NOT
# 13237  82921                [report, garbage, dont, give, crap]       OFF
# 13238  27429                                            [pussy]       OFF
# 13239  46552  [spanishrevenge, vs, justice, human, rights, f...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %% [markdown]
# ## Lemmatising

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
def get_wordnet_POS(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}
    return tag_dict.get(word, wordnet.NOUN)

# %%
def lemm(tweet):
    return [lemmatizer.lemmatize(i, get_wordnet_POS(i)) for i in tweet]

# %%
df['tweet'] = df['tweet'].apply(lemm)

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426                      [ask, native, american, take]       OFF
# 1      90194  [go, home, ’, drunk, maga, trump, 👊, 🇺, 🇸, 👊, ...       OFF
# 2      16820  [amazon, investigating, chinese, employee, sel...       NOT
# 3      62688  [someone, shouldve, taken, piece, shit, volcan...       OFF
# 4      43605  [obama, wanted, liberal, amp, illegals, move, ...       NOT
# ...      ...                                                ...       ...
# 13235  95338  [sometimes, get, strong, vibe, people, man, ’,...       OFF
# 13236  67210  [benidorm, ✅, creamfields, ✅, maga, ✅, shabby,...       NOT
# 13237  82921                [report, garbage, dont, give, crap]       OFF
# 13238  27429                                            [pussy]       OFF
# 13239  46552  [spanishrevenge, v, justice, human, right, fre...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %% [markdown]
# ## Saving Processed Training Data

# %%
df.to_csv('processed_train.csv')

# %% [markdown]
# ## Pre-Processing Unlabelled Data

# %%
df_unlab = pd.read_csv(r"C:\Users\suhas\Documents\College Projects\SSL-Offensive-Lang-Detection-Social-Media\testset-levela.tsv", sep='\t')

# %%
df_unlab
# Out:
#         id                                              tweet
# 0    15923  #WhoIsQ #WheresTheServer #DumpNike #DECLASFISA...
# 1    27014  #ConstitutionDay is revered by Conservatives, ...
# 2    30530  #FOXNews #NRA #MAGA #POTUS #TRUMP #2ndAmendmen...
# 3    13876  #Watching #Boomer getting the news that she is...
# 4    60133  #NoPasaran: Unity demo to oppose the far-right...
# ..     ...                                                ...
# 855  73439  #DespicableDems lie again about rifles. Dem Di...
# 856  25657  #MeetTheSpeakers 🙌 @USER will present in our e...
# 857  67018  3 people just unfollowed me for talking about ...
# 858  50665  #WednesdayWisdom Antifa calls the right fascis...
# 859  24583      #Kavanaugh typical #liberals , #Democrats URL
#
# [860 rows x 2 columns]

# %%
df_unlab = df_unlab.append(pd.read_csv(r"C:\Users\suhas\Documents\College Projects\SSL-Offensive-Lang-Detection-Social-Media\testset-levelb.tsv", sep='\t'))

# %%
df_unlab
# Out:
#         id                                              tweet
# 0    15923  #WhoIsQ #WheresTheServer #DumpNike #DECLASFISA...
# 1    27014  #ConstitutionDay is revered by Conservatives, ...
# 2    30530  #FOXNews #NRA #MAGA #POTUS #TRUMP #2ndAmendmen...
# 3    13876  #Watching #Boomer getting the news that she is...
# 4    60133  #NoPasaran: Unity demo to oppose the far-right...
# ..     ...                                                ...
# 235  22569  #Antifa are mentally unstable cowards, pretend...
# 236  48938  @USER @USER And Browning looked like dog shit ...
# 237  41438                All two of them taste like ass. URL
# 238  73439  #DespicableDems lie again about rifles. Dem Di...
# 239  67018  3 people just unfollowed me for talking about ...
#
# [1100 rows x 2 columns]

# %%
df_unlab = df_unlab.append(pd.read_csv(r"C:\Users\suhas\Documents\College Projects\SSL-Offensive-Lang-Detection-Social-Media\testset-levelc.tsv", sep='\t'))

# %%
df_unlab
# Out:
#         id                                              tweet
# 0    15923  #WhoIsQ #WheresTheServer #DumpNike #DECLASFISA...
# 1    27014  #ConstitutionDay is revered by Conservatives, ...
# 2    30530  #FOXNews #NRA #MAGA #POTUS #TRUMP #2ndAmendmen...
# 3    13876  #Watching #Boomer getting the news that she is...
# 4    60133  #NoPasaran: Unity demo to oppose the far-right...
# ..     ...                                                ...
# 208  30778  #StopEtchecopar? Fuck you all 🖕🖕🖕🖕🖕 Que florez...
# 209  22569  #Antifa are mentally unstable cowards, pretend...
# 210  48938  @USER @USER And Browning looked like dog shit ...
# 211  41438                All two of them taste like ass. URL
# 212  73439  #DespicableDems lie again about rifles. Dem Di...
#
# [1313 rows x 2 columns]

# %%
df_unlab = df_unlab.reset_index().drop(['index'], axis=1)

# %%
df_unlab
# Out:
#          id                                              tweet
# 0     15923  #WhoIsQ #WheresTheServer #DumpNike #DECLASFISA...
# 1     27014  #ConstitutionDay is revered by Conservatives, ...
# 2     30530  #FOXNews #NRA #MAGA #POTUS #TRUMP #2ndAmendmen...
# 3     13876  #Watching #Boomer getting the news that she is...
# 4     60133  #NoPasaran: Unity demo to oppose the far-right...
# ...     ...                                                ...
# 1308  30778  #StopEtchecopar? Fuck you all 🖕🖕🖕🖕🖕 Que florez...
# 1309  22569  #Antifa are mentally unstable cowards, pretend...
# 1310  48938  @USER @USER And Browning looked like dog shit ...
# 1311  41438                All two of them taste like ass. URL
# 1312  73439  #DespicableDems lie again about rifles. Dem Di...
#
# [1313 rows x 2 columns]

# %% [markdown]
# ## Twitter Pre-Processing

# %%
df_unlab['tweet'] = df_unlab['tweet'].str.replace('@USER','')

# %%
df_unlab
# Out:
#          id                                              tweet
# 0     15923  #WhoIsQ #WheresTheServer #DumpNike #DECLASFISA...
# 1     27014  #ConstitutionDay is revered by Conservatives, ...
# 2     30530  #FOXNews #NRA #MAGA #POTUS #TRUMP #2ndAmendmen...
# 3     13876  #Watching #Boomer getting the news that she is...
# 4     60133  #NoPasaran: Unity demo to oppose the far-right...
# ...     ...                                                ...
# 1308  30778  #StopEtchecopar? Fuck you all 🖕🖕🖕🖕🖕 Que florez...
# 1309  22569  #Antifa are mentally unstable cowards, pretend...
# 1310  48938    And Browning looked like dog shit against th...
# 1311  41438                All two of them taste like ass. URL
# 1312  73439  #DespicableDems lie again about rifles. Dem Di...
#
# [1313 rows x 2 columns]

# %%
df_unlab['tweet'] = df_unlab['tweet'].apply(hyperlink)

# %%
df_unlab
# Out:
#          id                                              tweet
# 0     15923  #WhoIsQ #WheresTheServer #DumpNike #DECLASFISA...
# 1     27014  #ConstitutionDay is revered by Conservatives, ...
# 2     30530  #FOXNews #NRA #MAGA #POTUS #TRUMP #2ndAmendmen...
# 3     13876  #Watching #Boomer getting the news that she is...
# 4     60133  #NoPasaran: Unity demo to oppose the far-right...
# ...     ...                                                ...
# 1308  30778  #StopEtchecopar? Fuck you all 🖕🖕🖕🖕🖕 Que florez...
# 1309  22569  #Antifa are mentally unstable cowards, pretend...
# 1310  48938    And Browning looked like dog shit against th...
# 1311  41438                All two of them taste like ass. URL
# 1312  73439  #DespicableDems lie again about rifles. Dem Di...
#
# [1313 rows x 2 columns]

# %%
df_unlab['tweet']= df_unlab['tweet'].apply(retweets)

# %%
df_unlab
# Out:
#          id                                              tweet
# 0     15923  #WhoIsQ #WheresTheServer #DumpNike #DECLASFISA...
# 1     27014  #ConstitutionDay is revered by Conservatives, ...
# 2     30530  #FOXNews #NRA #MAGA #POTUS #TRUMP #2ndAmendmen...
# 3     13876  #Watching #Boomer getting the news that she is...
# 4     60133  #NoPasaran: Unity demo to oppose the far-right...
# ...     ...                                                ...
# 1308  30778  #StopEtchecopar? Fuck you all 🖕🖕🖕🖕🖕 Que florez...
# 1309  22569  #Antifa are mentally unstable cowards, pretend...
# 1310  48938    And Browning looked like dog shit against th...
# 1311  41438                All two of them taste like ass. URL
# 1312  73439  #DespicableDems lie again about rifles. Dem Di...
#
# [1313 rows x 2 columns]

# %%
df_unlab['tweet'] = df_unlab['tweet'].apply(split_hashtag)

# %%
df_unlab
# Out:
#          id                                              tweet
# 0     15923  WhoIsQ WheresTheServer DumpNike DECLASFISA Dem...
# 1     27014  ConstitutionDay is revered by Conservatives, h...
# 2     30530  FOXNews NRA MAGA POTUS TRUMP 2ndAmendment RNC ...
# 3     13876  Watching Boomer getting the news that she is s...
# 4     60133  NoPasaran: Unity demo to oppose the far-right ...
# ...     ...                                                ...
# 1308  30778  StopEtchecopar? Fuck you all 🖕🖕🖕🖕🖕 Que florezc...
# 1309  22569  Antifa are mentally unstable cowards, pretendi...
# 1310  48938    And Browning looked like dog shit against th...
# 1311  41438                All two of them taste like ass. URL
# 1312  73439  DespicableDems lie again about rifles. Dem Dis...
#
# [1313 rows x 2 columns]

# %%
df_unlab['tweet'] = df_unlab['tweet'].apply(join_words)

# %%
df_unlab
# Out:
#          id                                              tweet
# 0     15923  Who Is Q Wheres The Server Dump Nike DECLASFIS...
# 1     27014  Constitution Day is revered by Conservatives, ...
# 2     30530  FOXNews NRA MAGA POTUS TRUMP 2nd Amendment RNC...
# 3     13876  Watching Boomer getting the news that she is s...
# 4     60133  No Pasaran: Unity demo to oppose the far-right...
# ...     ...                                                ...
# 1308  30778  Stop Etchecopar? Fuck you all 🖕🖕🖕🖕🖕 Que florez...
# 1309  22569  Antifa are mentally unstable cowards, pretendi...
# 1310  48938    And Browning looked like dog shit against th...
# 1311  41438                All two of them taste like ass. URL
# 1312  73439  Despicable Dems lie again about rifles. Dem Di...
#
# [1313 rows x 2 columns]

# %% [markdown]
# ## RemovingNumbers

# %%
df_unlab['tweet'] = df_unlab['tweet'].replace('\d+', '', regex=True)

# %%
df_unlab
# Out:
#          id                                              tweet
# 0     15923  Who Is Q Wheres The Server Dump Nike DECLASFIS...
# 1     27014  Constitution Day is revered by Conservatives, ...
# 2     30530  FOXNews NRA MAGA POTUS TRUMP nd Amendment RNC ...
# 3     13876  Watching Boomer getting the news that she is s...
# 4     60133  No Pasaran: Unity demo to oppose the far-right...
# ...     ...                                                ...
# 1308  30778  Stop Etchecopar? Fuck you all 🖕🖕🖕🖕🖕 Que florez...
# 1309  22569  Antifa are mentally unstable cowards, pretendi...
# 1310  48938    And Browning looked like dog shit against th...
# 1311  41438                All two of them taste like ass. URL
# 1312  73439  Despicable Dems lie again about rifles. Dem Di...
#
# [1313 rows x 2 columns]

# %% [markdown]
# ## Removing Punctuation

# %%
df_unlab['tweet'] = df_unlab['tweet'].str.replace('[{}]'.format(string.punctuation), '')
# Out:
# <ipython-input-35-91cd49cefc87>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_unlab['tweet'] = df_unlab['tweet'].str.replace('[{}]'.format(string.punctuation), '')

# %%
df_unlab
# Out:
#          id                                              tweet
# 0     15923  Who Is Q Wheres The Server Dump Nike DECLASFIS...
# 1     27014  Constitution Day is revered by Conservatives h...
# 2     30530  FOXNews NRA MAGA POTUS TRUMP nd Amendment RNC ...
# 3     13876  Watching Boomer getting the news that she is s...
# 4     60133  No Pasaran Unity demo to oppose the farright i...
# ...     ...                                                ...
# 1308  30778  Stop Etchecopar Fuck you all 🖕🖕🖕🖕🖕 Que florezc...
# 1309  22569  Antifa are mentally unstable cowards pretendin...
# 1310  48938    And Browning looked like dog shit against th...
# 1311  41438                 All two of them taste like ass URL
# 1312  73439  Despicable Dems lie again about rifles Dem Dis...
#
# [1313 rows x 2 columns]

# %% [markdown]
# ## Removing Whitespace

# %%
df_unlab['tweet'] = df_unlab['tweet'].str.strip()

# %%
df_unlab
# Out:
#          id                                              tweet
# 0     15923  Who Is Q Wheres The Server Dump Nike DECLASFIS...
# 1     27014  Constitution Day is revered by Conservatives h...
# 2     30530  FOXNews NRA MAGA POTUS TRUMP nd Amendment RNC ...
# 3     13876  Watching Boomer getting the news that she is s...
# 4     60133  No Pasaran Unity demo to oppose the farright i...
# ...     ...                                                ...
# 1308  30778  Stop Etchecopar Fuck you all 🖕🖕🖕🖕🖕 Que florezc...
# 1309  22569  Antifa are mentally unstable cowards pretendin...
# 1310  48938  And Browning looked like dog shit against the ...
# 1311  41438                 All two of them taste like ass URL
# 1312  73439  Despicable Dems lie again about rifles Dem Dis...
#
# [1313 rows x 2 columns]

# %% [markdown]
# ## Converting to lowercase

# %%
df_unlab['tweet'] = df_unlab['tweet'].str.lower()

# %%
df_unlab
# Out:
#          id                                              tweet
# 0     15923  who is q wheres the server dump nike declasfis...
# 1     27014  constitution day is revered by conservatives h...
# 2     30530  foxnews nra maga potus trump nd amendment rnc ...
# 3     13876  watching boomer getting the news that she is s...
# 4     60133  no pasaran unity demo to oppose the farright i...
# ...     ...                                                ...
# 1308  30778  stop etchecopar fuck you all 🖕🖕🖕🖕🖕 que florezc...
# 1309  22569  antifa are mentally unstable cowards pretendin...
# 1310  48938  and browning looked like dog shit against the ...
# 1311  41438                 all two of them taste like ass url
# 1312  73439  despicable dems lie again about rifles dem dis...
#
# [1313 rows x 2 columns]

# %% [markdown]
# ## Removing Stop Words

# %%
from nltk.corpus import stopwords  
from nltk.tokenize import TweetTokenizer 
tokenizer = TweetTokenizer(preserve_case=True, strip_handles=True, reduce_len=True)

# %%
def token(tweet):
    return tokenizer.tokenize(tweet)

# %%
df_unlab['tweet'] = df_unlab['tweet'].apply(token)

# %%
df_unlab
# Out:
#          id                                              tweet
# 0     15923  [who, is, q, wheres, the, server, dump, nike, ...
# 1     27014  [constitution, day, is, revered, by, conservat...
# 2     30530  [foxnews, nra, maga, potus, trump, nd, amendme...
# 3     13876  [watching, boomer, getting, the, news, that, s...
# 4     60133  [no, pasaran, unity, demo, to, oppose, the, fa...
# ...     ...                                                ...
# 1308  30778  [stop, etchecopar, fuck, you, all, 🖕, 🖕, 🖕, qu...
# 1309  22569  [antifa, are, mentally, unstable, cowards, pre...
# 1310  48938  [and, browning, looked, like, dog, shit, again...
# 1311  41438        [all, two, of, them, taste, like, ass, url]
# 1312  73439  [despicable, dems, lie, again, about, rifles, ...
#
# [1313 rows x 2 columns]

# %%
stop_words = set(stopwords.words('english'))

# %%
def remove(tweet):
    return [i for i in tweet if i not in stop_words]

# %%
df_unlab['tweet'] = df_unlab['tweet'].apply(remove)

# %%
df_unlab
# Out:
#          id                                              tweet
# 0     15923  [q, wheres, server, dump, nike, declasfisa, de...
# 1     27014  [constitution, day, revered, conservatives, ha...
# 2     30530  [foxnews, nra, maga, potus, trump, nd, amendme...
# 3     13876  [watching, boomer, getting, news, still, parol...
# 4     60133  [pasaran, unity, demo, oppose, farright, londo...
# ...     ...                                                ...
# 1308  30778  [stop, etchecopar, fuck, 🖕, 🖕, 🖕, que, florezc...
# 1309  22569  [antifa, mentally, unstable, cowards, pretendi...
# 1310  48938  [browning, looked, like, dog, shit, fcs, schoo...
# 1311  41438                       [two, taste, like, ass, url]
# 1312  73439  [despicable, dems, lie, rifles, dem, distorted...
#
# [1313 rows x 2 columns]

# %% [markdown]
# ## Lemmatising

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
def get_wordnet_POS(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}
    return tag_dict.get(word, wordnet.NOUN)

# %%
def lemm(tweet):
    return [lemmatizer.lemmatize(i, get_wordnet_POS(i)) for i in tweet]

# %%
df_unlab
# Out:
#          id                                              tweet
# 0     15923  [q, wheres, server, dump, nike, declasfisa, de...
# 1     27014  [constitution, day, revered, conservatives, ha...
# 2     30530  [foxnews, nra, maga, potus, trump, nd, amendme...
# 3     13876  [watching, boomer, getting, news, still, parol...
# 4     60133  [pasaran, unity, demo, oppose, farright, londo...
# ...     ...                                                ...
# 1308  30778  [stop, etchecopar, fuck, 🖕, 🖕, 🖕, que, florezc...
# 1309  22569  [antifa, mentally, unstable, cowards, pretendi...
# 1310  48938  [browning, looked, like, dog, shit, fcs, schoo...
# 1311  41438                       [two, taste, like, ass, url]
# 1312  73439  [despicable, dems, lie, rifles, dem, distorted...
#
# [1313 rows x 2 columns]

# %%
df_unlab.to_csv('processed_unlab.csv')
