# %%
import pandas as pd
import nltk
import string
import re

# %% [markdown]
# ## Importing

# %%
df = pd.read_csv(r"C:\Users\suhas\Documents\College Projects\SSL-Offensive-Lang-Detection-Social-Media\OLIDv1.0\olid-training-v1.0.tsv", sep="\t")

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426  @USER She should ask a few native Americans wh...       OFF
# 1      90194  @USER @USER Go home you’re drunk!!! @USER #MAG...       OFF
# 2      16820  Amazon is investigating Chinese employees who ...       NOT
# 3      62688  @USER Someone should'veTaken" this piece of sh...       OFF
# 4      43605  @USER @USER Obama wanted liberals &amp; illega...       NOT
# ...      ...                                                ...       ...
# 13235  95338  @USER Sometimes I get strong vibes from people...       OFF
# 13236  67210  Benidorm ✅  Creamfields ✅  Maga ✅   Not too sh...       NOT
# 13237  82921  @USER And why report this garbage.  We don't g...       OFF
# 13238  27429                                        @USER Pussy       OFF
# 13239  46552  #Spanishrevenge vs. #justice #HumanRights and ...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %% [markdown]
# ## Twitter Pre-Processing

# %%
df['tweet'] = df['tweet'].str.replace('@USER','')

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426   She should ask a few native Americans what th...       OFF
# 1      90194    Go home you’re drunk!!!  #MAGA #Trump2020 👊🇺...       OFF
# 2      16820  Amazon is investigating Chinese employees who ...       NOT
# 3      62688   Someone should'veTaken" this piece of shit to...       OFF
# 4      43605    Obama wanted liberals &amp; illegals to move...       NOT
# ...      ...                                                ...       ...
# 13235  95338   Sometimes I get strong vibes from people and ...       OFF
# 13236  67210  Benidorm ✅  Creamfields ✅  Maga ✅   Not too sh...       NOT
# 13237  82921   And why report this garbage.  We don't give a...       OFF
# 13238  27429                                              Pussy       OFF
# 13239  46552  #Spanishrevenge vs. #justice #HumanRights and ...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %%
# Removing hyperlinks
def hyperlink(tweet):
    return re.sub(r'https?:\/\/.*[\r\n]*', '', tweet)

# %%
df['tweet'] = df['tweet'].apply(hyperlink)

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426   She should ask a few native Americans what th...       OFF
# 1      90194    Go home you’re drunk!!!  #MAGA #Trump2020 👊🇺...       OFF
# 2      16820  Amazon is investigating Chinese employees who ...       NOT
# 3      62688   Someone should'veTaken" this piece of shit to...       OFF
# 4      43605    Obama wanted liberals &amp; illegals to move...       NOT
# ...      ...                                                ...       ...
# 13235  95338   Sometimes I get strong vibes from people and ...       OFF
# 13236  67210  Benidorm ✅  Creamfields ✅  Maga ✅   Not too sh...       NOT
# 13237  82921   And why report this garbage.  We don't give a...       OFF
# 13238  27429                                              Pussy       OFF
# 13239  46552  #Spanishrevenge vs. #justice #HumanRights and ...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %%
# Removing retweets
def retweets(tweet):
    return re.sub(r'^RT[\s]+', '', tweet)

# %%
df['tweet'] = df['tweet'].apply(retweets)

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426   She should ask a few native Americans what th...       OFF
# 1      90194    Go home you’re drunk!!!  #MAGA #Trump2020 👊🇺...       OFF
# 2      16820  Amazon is investigating Chinese employees who ...       NOT
# 3      62688   Someone should'veTaken" this piece of shit to...       OFF
# 4      43605    Obama wanted liberals &amp; illegals to move...       NOT
# ...      ...                                                ...       ...
# 13235  95338   Sometimes I get strong vibes from people and ...       OFF
# 13236  67210  Benidorm ✅  Creamfields ✅  Maga ✅   Not too sh...       NOT
# 13237  82921   And why report this garbage.  We don't give a...       OFF
# 13238  27429                                              Pussy       OFF
# 13239  46552  #Spanishrevenge vs. #justice #HumanRights and ...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %%
pattern = re.compile(r"[A-Z][a-z]+|\d+|[A-Z]+(?![a-z])")

def split_hashtag(tag):
    return pattern.findall(tag)

# %%
df['tweet'] = df['tweet'].apply(split_hashtag)

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426                                   [She, Americans]       OFF
# 1      90194                       [Go, MAGA, Trump, 2020, URL]       OFF
# 2      16820  [Amazon, Chinese, URL, Amazon, MAGA, KAG, CHIN...       NOT
# 3      62688                                   [Someone, Taken]       OFF
# 4      43605                                            [Obama]       NOT
# ...      ...                                                ...       ...
# 13235  95338                                 [Sometimes, I, DT]       OFF
# 13236  67210                 [Benidorm, Creamfields, Maga, Not]       NOT
# 13237  82921                                          [And, We]       OFF
# 13238  27429                                            [Pussy]       OFF
# 13239  46552  [Spanishrevenge, Human, Rights, Freedom, Of, E...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %% [markdown]
# ## Lower Case

# %%
df['tweet'] = df['tweet'].str.lower()

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426   she should ask a few native americans what th...       OFF
# 1      90194    go home you’re drunk!!!  #maga #trump2020 👊🇺...       OFF
# 2      16820  amazon is investigating chinese employees who ...       NOT
# 3      62688   someone should'vetaken" this piece of shit to...       OFF
# 4      43605    obama wanted liberals &amp; illegals to move...       NOT
# ...      ...                                                ...       ...
# 13235  95338   sometimes i get strong vibes from people and ...       OFF
# 13236  67210  benidorm ✅  creamfields ✅  maga ✅   not too sh...       NOT
# 13237  82921   and why report this garbage.  we don't give a...       OFF
# 13238  27429                                              pussy       OFF
# 13239  46552  #spanishrevenge vs. #justice #humanrights and ...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %% [markdown]
# ## Removing Numbers

# %%
df['tweet'] = df['tweet'].replace('\d+', '', regex=True)

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426  @user she should ask a few native americans wh...       OFF
# 1      90194  @user @user go home you’re drunk!!! @user #mag...       OFF
# 2      16820  amazon is investigating chinese employees who ...       NOT
# 3      62688  @user someone should'vetaken" this piece of sh...       OFF
# 4      43605  @user @user obama wanted liberals &amp; illega...       NOT
# ...      ...                                                ...       ...
# 13235  95338  @user sometimes i get strong vibes from people...       OFF
# 13236  67210  benidorm ✅  creamfields ✅  maga ✅   not too sh...       NOT
# 13237  82921  @user and why report this garbage.  we don't g...       OFF
# 13238  27429                                        @user pussy       OFF
# 13239  46552  #spanishrevenge vs. #justice #humanrights and ...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]

# %% [markdown]
# ## Removing Punctuation

# %%
df['tweet'] = df['tweet'].str.replace('[{}]'.format(string.punctuation), '')
# Out:
# C:\Users\suhas\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#           id                                              tweet subtask_a  \
# 0      86426  user she should ask a few native americans wha...       OFF
# 1      90194  user user go home you’re drunk user maga trump...       OFF
# 2      16820  amazon is investigating chinese employees who ...       NOT
# 3      62688  user someone shouldvetaken this piece of shit ...       OFF
# 4      43605  user user obama wanted liberals amp illegals t...       NOT
# ...      ...                                                ...       ...
# 13235  95338  user sometimes i get strong vibes from people ...       OFF
# 13236  67210  benidorm ✅  creamfields ✅  maga ✅   not too sh...       NOT
# 13237  82921  user and why report this garbage  we dont give...       OFF
# 13238  27429                                         user pussy       OFF
# 13239  46552  spanishrevenge vs justice humanrights and free...       NOT
#
#       subtask_b subtask_c
# 0           UNT       NaN
# 1           TIN       IND
# 2           NaN       NaN
# 3           UNT       NaN
# 4           NaN       NaN
# ...         ...       ...
# 13235       TIN       IND
# 13236       NaN       NaN
# 13237       TIN       OTH
# 13238       UNT       NaN
# 13239       NaN       NaN
#
# [13240 rows x 5 columns]
